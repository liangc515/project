# %% [markdown]
# ## 確認套件已經安裝

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import numpy as np

from google.colab import files

from sklearn.utils import shuffle

import tensorflow as tf
import tensorflow.keras as keras
from keras.utils import to_categorical

import matplotlib.pyplot as plt

from pylab import rcParams

# !pip install -q requests

# %% [markdown]
# ## 下載並開啟資料檔，將內容存放到變數 pkgo
# 程式會自動抓取我們為你準備好的資料集 pkgo_nyc_class5.csv.bz2
#
# 如果下載失敗，請自行上傳檔案

# %%
import requests

# 設定 GitHub 下戴網址
data_file = 'pkgo_nyc_class5.csv.bz2'
dataset_url = 'https://github.com/hdyen/hands-on-dl/raw/master/PKGO/dataset/'
data_url = '{}{}'.format(dataset_url, data_file)

if not os.path.exists(data_file):
    try:
        r = requests.get(data_url)
        # 將從 GitHub 下戴的資料集寫入 colab 本地端
        with open(data_file, 'wb') as f:
            f.write(r.content)
    except:
        # 如果無法從 GitHub 下戴資料，則自行上傳 pkgo_nyc_class5.csv.bz2
        print('下戴之敗！請將本機端的資料 pkgo_nyc_class5.csv.bz2 上傳到 colab 環境')
        uploaded = files.upload()

pkgo = pd.read_csv(data_file)
pkgo.shape
# Out:
# (1836, 201)

# %%
def Xy_split(pkgo):
  num_cols = pkgo.shape[1]
  # 取class之前的所有features當作X 做待會的輸入數據
  X = pkgo.iloc[:, :num_cols-1]
  # 取class當作y label
  y = pkgo['class']
  
  # 型別轉換，確保資料型態正確
  X = X.astype(np.float32)
  y = y.astype(np.int)
  
  # 對 y 做 one-hot encoding
  y = to_categorical(y)
  
  # 打亂資料集
  X, y = shuffle(X, y)
  
  return X, y

X, y = Xy_split(pkgo)

X.shape, y.shape
# Out:
# ((1836, 200), (1836, 5))

# %%
#切分訓練集與測試集
x_train, y_train, x_test, y_test = X[0:1500], y[0:1500], X[1500::], y[1500::]
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1500, 200), (1500, 5), (336, 200), (336, 5))

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/model_training_tip.png)

# %% [markdown]
# ## 建構一個模型 (以目前的學到的最佳元件組合)

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/component_selection_bast_subset.png)

# %%
''' Import keras to build a DL model '''
from keras.models import Model, Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

def build_model(X):
  # 選擇Sequential 次序性為這次深度學習模型
  model = Sequential()
  
  # 第一層的hidden laryer (512 neurons)與指定 input 的維度
  model.add(Dense(512, input_dim=X.shape[-1]))
  model.add(Activation('relu'))
  
  # 加入第二層 hidden layer (512 neurons)
  model.add(Dense(512))
  model.add(Activation('relu'))
  
  # 加入 output layer (5 neurons)
  model.add(Dense(5))
  model.add(Activation('softmax'))
  return model

# %% [markdown]
# ## 觀察Overfitting的問題

# %%
''' 編譯模型 '''
# 將建構好的模型存放至model變數
# 用ex06中，結果較優的Adam當作我們的 optimizer
# accuracy當作我們的指標
model = build_model(X)
optim = Adam(lr=1e-3)
model.compile(loss='categorical_crossentropy',
              optimizer=optim,
              metrics=['accuracy'])

batch_size = 32
epochs = 100

history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              shuffle=True,
              validation_split=0.2)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 14ms/step - loss: 3.7253 - accuracy: 0.3557 - val_loss: 1.2001 - val_accuracy: 0.6233
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2280 - accuracy: 0.5829 - val_loss: 1.1633 - val_accuracy: 0.5867
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1414 - accuracy: 0.5708 - val_loss: 0.9948 - val_accuracy: 0.6667
# Epoch 4/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9851 - accuracy: 0.6576 - val_loss: 1.1411 - val_accuracy: 0.5467
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.1152 - accuracy: 0.5956 - val_loss: 1.0681 - val_accuracy: 0.6367
# Epoch 6/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9828 - accuracy: 0.6381 - val_loss: 1.1217 - val_accuracy: 0.5733
# Epoch 7/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9225 - accuracy: 0.6815 - val_loss: 0.9120 - val_accuracy: 0.7033
# Epoch 8/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9143 - accuracy: 0.6621 - val_loss: 0.9875 - val_accuracy: 0.6733
# Epoch 9/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.9163 - accuracy: 0.6654 - val_loss: 0.8995 - val_accuracy: 0.7033
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8015 - accuracy: 0.7015 - val_loss: 0.9814 - val_accuracy: 0.6933
# Epoch 11/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7660 - accuracy: 0.7306 - val_loss: 0.9005 - val_accuracy: 0.7167
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.7773 - val_loss: 1.0742 - val_accuracy: 0.6933
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8178 - accuracy: 0.7262 - val_loss: 0.9619 - val_accuracy: 0.6433
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7042 - accuracy: 0.7419 - val_loss: 1.0036 - val_accuracy: 0.6367
# Epoch 15/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6813 - accuracy: 0.7541 - val_loss: 0.9201 - val_accuracy: 0.6667
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6386 - accuracy: 0.7748 - val_loss: 0.9291 - val_accuracy: 0.7167
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6398 - accuracy: 0.7755 - val_loss: 1.1176 - val_accuracy: 0.6800
# Epoch 18/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.7352 - val_loss: 1.0152 - val_accuracy: 0.7000
# Epoch 19/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6469 - accuracy: 0.7657 - val_loss: 1.0477 - val_accuracy: 0.7000
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.7601 - val_loss: 0.9309 - val_accuracy: 0.6867
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.8020 - val_loss: 0.9624 - val_accuracy: 0.7300
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.8116 - val_loss: 1.1289 - val_accuracy: 0.6867
# Epoch 23/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5013 - accuracy: 0.8209 - val_loss: 1.0624 - val_accuracy: 0.6567
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5120 - accuracy: 0.8233 - val_loss: 1.0735 - val_accuracy: 0.6800
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.8450 - val_loss: 1.0146 - val_accuracy: 0.6967
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4780 - accuracy: 0.8415 - val_loss: 1.0725 - val_accuracy: 0.6600
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4870 - accuracy: 0.8266 - val_loss: 1.0507 - val_accuracy: 0.7000
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4075 - accuracy: 0.8821 - val_loss: 1.1299 - val_accuracy: 0.6733
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.8511 - val_loss: 1.0258 - val_accuracy: 0.7067
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.8663 - val_loss: 1.2109 - val_accuracy: 0.7033
# Epoch 31/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4261 - accuracy: 0.8464 - val_loss: 1.1506 - val_accuracy: 0.6900
# Epoch 32/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.8522 - val_loss: 1.0688 - val_accuracy: 0.6667
# Epoch 33/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3380 - accuracy: 0.8888 - val_loss: 1.1424 - val_accuracy: 0.7100
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3043 - accuracy: 0.9035 - val_loss: 1.0947 - val_accuracy: 0.6900
# Epoch 35/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3325 - accuracy: 0.8763 - val_loss: 1.1037 - val_accuracy: 0.7067
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2538 - accuracy: 0.9220 - val_loss: 1.2431 - val_accuracy: 0.7167
# Epoch 37/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2997 - accuracy: 0.8948 - val_loss: 1.3038 - val_accuracy: 0.6233
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2975 - accuracy: 0.8890 - val_loss: 1.1638 - val_accuracy: 0.6733
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.8842 - val_loss: 1.5239 - val_accuracy: 0.6600
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.8410 - val_loss: 1.1125 - val_accuracy: 0.7133
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.9162 - val_loss: 1.2233 - val_accuracy: 0.7033
# Epoch 42/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2396 - accuracy: 0.9048 - val_loss: 1.2793 - val_accuracy: 0.6833
# Epoch 43/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2078 - accuracy: 0.9394 - val_loss: 1.2358 - val_accuracy: 0.7000
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2277 - accuracy: 0.9211 - val_loss: 1.3229 - val_accuracy: 0.7033
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1683 - accuracy: 0.9448 - val_loss: 1.3602 - val_accuracy: 0.7100
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9402 - val_loss: 1.3223 - val_accuracy: 0.6667
# Epoch 47/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1545 - accuracy: 0.9580 - val_loss: 1.3675 - val_accuracy: 0.7033
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1847 - accuracy: 0.9330 - val_loss: 1.4358 - val_accuracy: 0.7000
# Epoch 49/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9485 - val_loss: 1.4363 - val_accuracy: 0.6933
# Epoch 50/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2011 - accuracy: 0.9294 - val_loss: 1.4772 - val_accuracy: 0.6733
# Epoch 51/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.2028 - accuracy: 0.9320 - val_loss: 1.3566 - val_accuracy: 0.7267
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.9538 - val_loss: 1.4481 - val_accuracy: 0.6900
# Epoch 53/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.9653 - val_loss: 1.4745 - val_accuracy: 0.6867
# Epoch 54/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1258 - accuracy: 0.9630 - val_loss: 1.4750 - val_accuracy: 0.6533
# Epoch 55/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.9688 - val_loss: 1.5479 - val_accuracy: 0.7267
# Epoch 56/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0915 - accuracy: 0.9735 - val_loss: 1.4716 - val_accuracy: 0.6733
# Epoch 57/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0848 - accuracy: 0.9778 - val_loss: 1.6754 - val_accuracy: 0.7200
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9776 - val_loss: 1.5528 - val_accuracy: 0.6867
# Epoch 59/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9794 - val_loss: 1.5984 - val_accuracy: 0.6533
# Epoch 60/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0851 - accuracy: 0.9749 - val_loss: 1.5871 - val_accuracy: 0.6733
# Epoch 61/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9477 - val_loss: 1.6875 - val_accuracy: 0.6000
# Epoch 62/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9448 - val_loss: 1.6502 - val_accuracy: 0.7033
# Epoch 63/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9819 - val_loss: 1.6739 - val_accuracy: 0.6733
# Epoch 64/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9763 - val_loss: 1.6928 - val_accuracy: 0.6867
# Epoch 65/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9806 - val_loss: 1.7668 - val_accuracy: 0.7067
# Epoch 66/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9805 - val_loss: 1.7481 - val_accuracy: 0.6400
# Epoch 67/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9860 - val_loss: 1.8587 - val_accuracy: 0.7133
# Epoch 68/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9889 - val_loss: 1.7089 - val_accuracy: 0.6600
# Epoch 69/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 0.9895 - val_loss: 1.7956 - val_accuracy: 0.6800
# Epoch 70/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9971 - val_loss: 1.9398 - val_accuracy: 0.7200
# Epoch 71/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 0.9867 - val_loss: 2.0256 - val_accuracy: 0.7300
# Epoch 72/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9531 - val_loss: 1.8996 - val_accuracy: 0.6700
# Epoch 73/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9552 - val_loss: 1.7789 - val_accuracy: 0.6767
# Epoch 74/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1140 - accuracy: 0.9661 - val_loss: 1.9106 - val_accuracy: 0.7233
# Epoch 75/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9524 - val_loss: 1.8453 - val_accuracy: 0.7133
# Epoch 76/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9768 - val_loss: 1.8037 - val_accuracy: 0.7133
# Epoch 77/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0849 - accuracy: 0.9723 - val_loss: 1.7784 - val_accuracy: 0.6833
# Epoch 78/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9695 - val_loss: 1.8432 - val_accuracy: 0.6800
# Epoch 79/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9825 - val_loss: 1.8732 - val_accuracy: 0.6733
# Epoch 80/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 1.8314 - val_accuracy: 0.6700
# Epoch 81/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9948 - val_loss: 1.9314 - val_accuracy: 0.6967
# Epoch 82/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9981 - val_loss: 1.8754 - val_accuracy: 0.6833
# Epoch 83/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 2.0253 - val_accuracy: 0.7100
# Epoch 84/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2.0260 - val_accuracy: 0.7167
# Epoch 85/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 2.0148 - val_accuracy: 0.7000
# Epoch 86/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 2.0337 - val_accuracy: 0.6933
# Epoch 87/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 2.0198 - val_accuracy: 0.6967
# Epoch 88/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.0856 - val_accuracy: 0.7133
# Epoch 89/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.0719 - val_accuracy: 0.6967
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.0891 - val_accuracy: 0.7000
# Epoch 91/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.0987 - val_accuracy: 0.6900
# Epoch 92/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.1409 - val_accuracy: 0.7067
# Epoch 93/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.1525 - val_accuracy: 0.7067
# Epoch 94/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.1718 - val_accuracy: 0.7033
# Epoch 95/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.1912 - val_accuracy: 0.7000
# Epoch 96/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.1834 - val_accuracy: 0.7000
# Epoch 97/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.2326 - val_accuracy: 0.7033
# Epoch 98/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.2614 - val_accuracy: 0.7133
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.2413 - val_accuracy: 0.7000
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.2269 - val_accuracy: 0.7000

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 10, 7

loss = history.history.get('loss')          # 取出訓練完成後loss的訓練數據
#val_loss = history.history.get('val_loss')  

acc = history.history.get('accuracy')            # 取出訓練完成後accuracy的訓練數據
#val_acc = history.history.get('val_accuracy')   
    
plt.figure(0)

plt.subplot(121)

# 繪出loss的線條
plt.plot(range(len(loss)), loss, label='Training Loss')
#plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.legend(loc='best')
plt.title('Loss')


plt.subplot(122)
# 繪出accuracy的線條
plt.plot(range(len(acc)), acc, label='Training Accuracy')
#plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.legend(loc='best')
plt.title('Accuracy')

plt.show()

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 10, 7

loss = history.history.get('loss')          # 取出訓練完成後loss的訓練數據
val_loss = history.history.get('val_loss')  # 取出訓練完成後val_loss的訓練數據

acc = history.history.get('accuracy')            # 取出訓練完成後accuracy的訓練數據
val_acc = history.history.get('val_accuracy')    # 取出訓練完成後val_accuracy的訓練數據
    
plt.figure(0)

plt.subplot(121)

# 個別繪出loss以及val_loss的線條
plt.plot(range(len(loss)), loss, label='Training Loss')
plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.legend(loc='best')
plt.title('Loss')


plt.subplot(122)
# 個別繪出accuracy以及val_accuracy的線條
plt.plot(range(len(acc)), acc, label='Training Accuracy')
plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.legend(loc='best')
plt.title('Accuracy')

plt.show()

# %%
#evaluate model
pred = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 11/11 - 0s - loss: 2.9070 - accuracy: 0.6577

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/overfitting-1.png)

# %% [markdown]
# ## 處理overfitting問題:
#
# 1.   Regularization
# 2.   Early Stop
# 3.   Dropout
# 4.   Batch Normalization
# 5.   其它: 增加樣本、資料增強(data augmentation)..etc.

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/regularization-1.png)

# %% [markdown]
# <hr/>

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/regularization-2.png)

# %% [markdown]
# <hr/>

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/L1_and_L2_balls.png)

# %% [markdown]
# #Regularization: 在模型建構時加入regularizer

# %%
''' Import keras to build a DL model '''
from keras.models import Model, Sequential
from keras.layers import Dense, Activation, LeakyReLU
from keras.optimizers import Adam
''' Import l1,l2 (regularizer) '''
from keras.regularizers import l1, l2, l1_l2

def build_model_Reg(X, l1_alpha, l2_alpha):
  # 選擇Sequential 次序性為這次深度學習模型
  model = Sequential()
  
  # 第一層的hidden laryer 並加入 regularizer _ l1、l2
  model.add(Dense(512, input_dim=X.shape[-1], kernel_regularizer=l1_l2(l1=l1_alpha, l2=l2_alpha)))
  model.add(Activation('relu'))
  
  # 第二層的hidden laryer 並加入 regularizer _ l1、l2
  model.add(Dense(512, kernel_regularizer=l1_l2(l1=l1_alpha, l2=l2_alpha)))
  model.add(Activation('relu'))
  
  # 加入 output layer (5 neurons)，也將regularization，l1、l2帶入
  model.add(Dense(5, kernel_regularizer=l1_l2(l1=l1_alpha, l2=l2_alpha)))
  model.add(Activation('softmax'))
  return model

# %% [markdown]
# **比較不同 regularizer 對訓練結果之差異**

# %%
#@title Regularizer Comparison { vertical-output: false, display-mode: "both" }

import keras.backend as K

# 建立一個list存放待會要做比較的 regularizer的值
l1_l2_list = [(0, 0), (0.0005, 0), (0, 0.0005), (0.0005, 0.0005)] #@param {type:"raw"}

batch_size = 32
epochs = 100
# 建立兩個train_list來儲存之後使用不同數值regularizer訓練出來的結果
train_loss_list = []
train_acc_list = []
# 建立兩個valid_list來儲存之後使用不同數值regularizer驗證出來的結果
valid_loss_list = []
valid_acc_list = []

# 將每一個不同的regularizer代入做訓練
for l1_alpha, l2_alpha in l1_l2_list:
  K.clear_session() # 清掉上次訓練的結果
  print('Building a model with regularizer L1: {}, L2: {}'.format(l1_alpha, l2_alpha))
    
  ''' 編譯模型 '''
# 將建構好的模型存放至model變數
# 用ex06中，結果較優的Adam當作我們的 optimizer
# accuracy當作我們的指標
  model_reg = build_model_Reg(X, l1_alpha, l2_alpha)
  optim = Adam(lr=1e-4, decay=1e-3)
  model_reg.compile(loss='categorical_crossentropy',
                optimizer=optim,
                metrics=['accuracy'])
  
  # 訓練參數設定都與前次模型訓練一樣！ 
  history_reg = model_reg.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                verbose=0,
                shuffle=True,
                validation_split=0.2)
  
  # 將(val)loss 和 (val)acc 儲存之後在裝進(valild)train_loss/acc變數中
  # 儲存每一個不同regularization的結果，最後用於繪製結果
  
  loss = history_reg.history.get('loss')
  acc = history_reg.history.get('accuracy')
  val_loss = history_reg.history.get('val_loss')
  val_acc = history_reg.history.get('val_accuracy')

  train_loss_list.append(loss)
  valid_loss_list.append(val_loss)
  train_acc_list.append(acc)
  valid_acc_list.append(val_acc)
# Out:
# Building a model with regularizer L1: 0, L2: 0
# Building a model with regularizer L1: 0.0005, L2: 0
# Building a model with regularizer L1: 0, L2: 0.0005
# Building a model with regularizer L1: 0.0005, L2: 0.0005

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 13, 4

for k in range(len(l1_l2_list)):
  plt.figure(0)
  
  plt.subplot(121)
  l1, l2 = l1_l2_list[k]
  loss = train_loss_list[k]
  val_loss = valid_loss_list[k]
  plt.plot(range(len(loss)), loss, label='Training')
  plt.plot(range(len(val_loss)), val_loss, label='Validation')
  title = 'Loss, L1: {}, L2: {}'.format(l1, l2)
  plt.ylim([0, 4.5])
  plt.title(title)
  
  plt.subplot(122)
  l1, l2 = l1_l2_list[k]
  acc = train_acc_list[k]
  val_acc = valid_acc_list[k]
  plt.plot(range(len(acc)), acc, label='Training')
  plt.plot(range(len(val_acc)), val_acc, label='Validation')
  title = 'Accuracy, L1: {}, L2: {}'.format(l1, l2)
  plt.ylim([0.2, 0.8])
  plt.title(title)
  
  plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

  plt.show()

# %%
#Regularization
pred_reg = model_reg.evaluate(x_test, y_test, verbose=2)
# Out:
# 11/11 - 0s - loss: 3.2970 - accuracy: 0.6696

# %% [markdown]
# # Early Stop: 在適當的訓練回合即停止訓練, 保留最好的參數訓練結果

# %%
n_patience = 20 # 訓練過程經過20次沒有進步之後停止

# %%
from keras.callbacks import EarlyStopping

# 建EarlyStopping，monitor以val_loss為主，經過五次patience，verbose=1：信息展示
early_stopping = EarlyStopping(monitor = 'val_loss', 
                 patience = n_patience, 
                 verbose = 1)

# %%
#Regularization設定: (示範期間先設0,不然會early stop機制會很慢觸發)
l1_alpha = 0.000
l2_alpha = 0.000

# %%
# 編譯模型
model_estop = build_model_Reg(X, l1_alpha, l2_alpha)
optim = Adam(lr=1e-3)
model_estop.compile(loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy'])

batch_size = 32
epochs = 100

# 訓練模型
history_estop = model_estop.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              shuffle=True,
              validation_split=0.2, callbacks=[early_stopping]) # 加上callbacks:earlystopping
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 9ms/step - loss: 3.7431 - accuracy: 0.3852 - val_loss: 1.3838 - val_accuracy: 0.5067
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2462 - accuracy: 0.5715 - val_loss: 1.1331 - val_accuracy: 0.5900
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1713 - accuracy: 0.5579 - val_loss: 1.2205 - val_accuracy: 0.6333
# Epoch 4/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0958 - accuracy: 0.6267 - val_loss: 1.0078 - val_accuracy: 0.6500
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0033 - accuracy: 0.6370 - val_loss: 0.9891 - val_accuracy: 0.6367
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9547 - accuracy: 0.6659 - val_loss: 0.9913 - val_accuracy: 0.6900
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9394 - accuracy: 0.6630 - val_loss: 1.0723 - val_accuracy: 0.5833
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9475 - accuracy: 0.6203 - val_loss: 1.1302 - val_accuracy: 0.5800
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0199 - accuracy: 0.6257 - val_loss: 0.9262 - val_accuracy: 0.6667
# Epoch 10/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8408 - accuracy: 0.7084 - val_loss: 0.8999 - val_accuracy: 0.6867
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7847 - accuracy: 0.7161 - val_loss: 0.9443 - val_accuracy: 0.6800
# Epoch 12/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7589 - accuracy: 0.7372 - val_loss: 1.1394 - val_accuracy: 0.6600
# Epoch 13/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7907 - accuracy: 0.7165 - val_loss: 0.9173 - val_accuracy: 0.6933
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7742 - accuracy: 0.7106 - val_loss: 0.9252 - val_accuracy: 0.6933
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6499 - accuracy: 0.7521 - val_loss: 1.0171 - val_accuracy: 0.6667
# Epoch 16/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.7159 - accuracy: 0.7252 - val_loss: 0.9069 - val_accuracy: 0.7267
# Epoch 17/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6111 - accuracy: 0.7700 - val_loss: 0.9407 - val_accuracy: 0.7067
# Epoch 18/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6165 - accuracy: 0.7654 - val_loss: 0.9301 - val_accuracy: 0.6767
# Epoch 19/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.7648 - val_loss: 0.9541 - val_accuracy: 0.6833
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5944 - accuracy: 0.7842 - val_loss: 1.0052 - val_accuracy: 0.7300
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5563 - accuracy: 0.8153 - val_loss: 0.9836 - val_accuracy: 0.7000
# Epoch 22/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6130 - accuracy: 0.7894 - val_loss: 1.0627 - val_accuracy: 0.7133
# Epoch 23/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5469 - accuracy: 0.8119 - val_loss: 0.9344 - val_accuracy: 0.7100
# Epoch 24/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5122 - accuracy: 0.8217 - val_loss: 0.9728 - val_accuracy: 0.6867
# Epoch 25/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.8394 - val_loss: 1.0988 - val_accuracy: 0.7233
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5851 - accuracy: 0.7900 - val_loss: 1.0490 - val_accuracy: 0.7467
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4513 - accuracy: 0.8408 - val_loss: 1.0089 - val_accuracy: 0.6800
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4399 - accuracy: 0.8462 - val_loss: 1.0197 - val_accuracy: 0.7233
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3847 - accuracy: 0.8756 - val_loss: 1.0541 - val_accuracy: 0.7267
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4240 - accuracy: 0.8299 - val_loss: 1.0651 - val_accuracy: 0.7300
# Epoch 00030: early stopping

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 10, 7

loss = history_estop.history.get('loss')
val_loss = history_estop.history.get('val_loss')

acc = history_estop.history.get('accuracy')
val_acc = history_estop.history.get('val_accuracy')

plt.figure(0)

plt.subplot(121)

plt.plot(range(len(loss)), loss, label='Training Loss')
plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.legend(loc='upper left')
plt.title('Loss')


plt.subplot(122)
plt.plot(range(len(acc)), acc, label='Training Accuracy')
plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Accuracy')

plt.show()

# %%
#early stop +　Regularization
pred_estop = model_estop.evaluate(x_test, y_test, verbose=2)
# Out:
# 11/11 - 0s - loss: 1.2927 - accuracy: 0.6905

# %% [markdown]
# # 使用Dropout
# 在模型訓練時，隨機將一些神經元關閉，避免神經元之間相互調適過度(prevents units from co-adapting too much)進行訓練，在Inference時打開所有神經元。
# [參考論文連結](https://jmlr.org/papers/volume15/srivastava14a/srivastava14a.pdf)

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/dropout.png)

# %% [markdown]
# **建構一個有dropout的DNN網路架構**

# %%
''' Import keras to build a DL model '''
from keras.models import Model, Sequential
from keras.layers import Dense, Activation, LeakyReLU, Dropout
from keras.optimizers import SGD, RMSprop, Adam
from keras.callbacks import EarlyStopping

def build_model_drp(X, drp_rate):
  model = Sequential()
  # 第一層的hidden laryer (512 neurons)與指定 input 的維度
  model.add(Dense(512, input_dim=X.shape[-1]))
  model.add(Activation('relu'))
  # 設定 dropout rate
  model.add(Dropout(drp_rate))
  # 第二層的hidden laryer (512 neurons)與指定 input 的維度
  model.add(Dense(512))
  model.add(Activation('relu'))   
  # 設定 dropout rate
  model.add(Dropout(drp_rate))
  model.add(Dense(5))
  model.add(Activation('softmax'))
  return model

# %% [markdown]
# ## 比較不同 Dropout rate 的結果

# %%
import keras.backend as K
#@title Dropout Comparison { vertical-output: false, display-mode: "both" }

# 建立一個list存放待會要做比較的 dropout rates
dropout_rates = [0, 0.1, 0.2, 0.4, 0.6, 0.8]  #@param {type:"raw"}

# 建立兩個train_list來儲存之後使用不同數值dropout rate訓練出來的結果
train_loss_list = []
train_acc_list = []

# 建立兩個valid_list來儲存之後使用不同數值dropout rate驗證出來的結果
valid_loss_list = []
valid_acc_list = []

# 將每一個不同的dropout rate代入做訓練
for drp_rate in dropout_rates:
  K.clear_session() # 清掉上次訓練的結果
  
  ''' 編譯模型 '''
  # 將建構好的模型存放至model變數
  # 用ex06中，結果較優的Adam當作我們的 optimizer
  # accuracy當作我們的指標
  model_drp = build_model_drp(x_train, drp_rate)
  optim = Adam(lr=1e-4)
  model_drp.compile(loss='categorical_crossentropy',
                optimizer=optim,
                metrics=['accuracy'])
  
  batch_size= 32
    epochs= 100
  n_patience= 20
  
  # 建EarlyStopping
  early_stopping = EarlyStopping(monitor = 'val_loss', 
                    patience = n_patience, 
                    verbose = 1)

  print('Training a model with dropout rate: {}'.format(drp_rate))
  history_drp = model_drp.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                verbose=0,
                shuffle=True,
                validation_split=0.2,
                callbacks=[early_stopping])
  
  # 將(val)loss 和 (val)acc 儲存之後在裝進(valild)train_loss/acc變數中
  # 儲存每一個不同regularization的結果，最後用於繪製結果
  
  loss = history_drp.history.get('loss')
  acc = history_drp.history.get('accuracy')
  val_loss = history_drp.history.get('val_loss')
  val_acc = history_drp.history.get('val_accuracy')
  
  train_loss_list.append(loss)
  train_acc_list.append(acc)
  valid_loss_list.append(val_loss)
  valid_acc_list.append(val_acc)
# Out:
# Training a model with dropout rate: 0
# Epoch 00074: early stopping
# Training a model with dropout rate: 0.1
# Epoch 00083: early stopping
# Training a model with dropout rate: 0.2
# Training a model with dropout rate: 0.4
# Epoch 00024: early stopping
# Training a model with dropout rate: 0.6
# Epoch 00026: early stopping
# Training a model with dropout rate: 0.8
# Epoch 00037: early stopping

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 13, 4

for k in range(len(dropout_rates)):
  plt.figure(0)
  
  drp_rate = dropout_rates[k]
  
  plt.subplot(121)
  loss = train_loss_list[k]
  val_loss = valid_loss_list[k]
  plt.plot(range(len(loss)), loss, label='Training')
  plt.plot(range(len(val_loss)), val_loss, label='Validation')
  title = 'Loss, Dropout rate: {}'.format(drp_rate)
  plt.ylim([0.0, 3.0])
  plt.title(title)
  
  plt.subplot(122)
  acc = train_acc_list[k]
  val_acc = valid_acc_list[k]
  plt.plot(range(len(acc)), acc, label='Training')
  plt.plot(range(len(val_acc)), val_acc, label='Validation')
  title = 'Accuracy, Dropout rate: {}'.format(drp_rate)
  plt.ylim([0.1, 0.9])
  plt.title(title)
  
  plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

  plt.show()

# %% [markdown]
# # 使用Batch Normalization
#
# Batch Normalization 的計算方式，先將 mini-batch 進行正規化(Normalize)至平均值為0、標準差為1，在y估計式引入學習參數scale(γ)和 shift(β)，讓模型學習其Batch Normalization後的特徵分佈如何透過scale及shift參數還原估計y值
# [參考論文連結(2015)](https://arxiv.org/pdf/1502.03167.pdf)
#
# ![alt text](https://miro.medium.com/max/651/1*-yCzc6YlJHXe7LmCpqQmkg.png)

# %%
''' Import keras to build a DL model '''
from keras.models import Model, Sequential
from keras.layers import Dense, Activation, LeakyReLU, Dropout, BatchNormalization
from keras.optimizers import SGD, RMSprop, Adam
from keras.callbacks import EarlyStopping

def build_model_bn(X, drp_rate=0.5):
  model = Sequential()
  # 第一層的hidden laryer (512 neurons)與指定 input 的維度
  model.add(Dense(512, input_dim=X.shape[-1]))

  #BatchNormalization layer加在Activation之前
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(drp_rate))

  # 第二層的hidden laryer (512 neurons)與指定 input 的維度
  model.add(Dense(512))

  #BatchNormalization layer加在Activation之前
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(drp_rate))

  model.add(Dense(5))
  model.add(Activation('softmax'))
  return model

# %%
from keras.callbacks import EarlyStopping

n_patience = 30

early_stopping = EarlyStopping(monitor = 'val_accuracy', 
                 patience = n_patience, 
                 verbose = 1)

# %%
''' 編譯模型 '''
model_bn = build_model_bn(x_train, 0.15)
optim = Adam(lr=1e-3)
model_bn.compile(loss='categorical_crossentropy',
              optimizer=optim,
              metrics=['accuracy'])

batch_size = 32
epochs = 100

history_bn = model_bn.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              shuffle=True,
              validation_split=0.2, callbacks=[early_stopping]) # 加上callbacks:earlystopping
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 11ms/step - loss: 1.6616 - accuracy: 0.3811 - val_loss: 1.9462 - val_accuracy: 0.3000
# Epoch 2/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.1908 - accuracy: 0.5814 - val_loss: 1.4821 - val_accuracy: 0.3967
# Epoch 3/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0007 - accuracy: 0.6368 - val_loss: 1.6697 - val_accuracy: 0.2700
# Epoch 4/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.9951 - accuracy: 0.6258 - val_loss: 1.6207 - val_accuracy: 0.3767
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8898 - accuracy: 0.6753 - val_loss: 1.1037 - val_accuracy: 0.5733
# Epoch 6/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8933 - accuracy: 0.6690 - val_loss: 0.9683 - val_accuracy: 0.6600
# Epoch 7/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7751 - accuracy: 0.7296 - val_loss: 0.9773 - val_accuracy: 0.6800
# Epoch 8/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8075 - accuracy: 0.6983 - val_loss: 0.9272 - val_accuracy: 0.7167
# Epoch 9/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7248 - accuracy: 0.7414 - val_loss: 0.9742 - val_accuracy: 0.6667
# Epoch 10/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7154 - accuracy: 0.7624 - val_loss: 1.1117 - val_accuracy: 0.6100
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 0.7385 - val_loss: 0.9984 - val_accuracy: 0.6233
# Epoch 12/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.7351 - val_loss: 1.0783 - val_accuracy: 0.5733
# Epoch 13/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6377 - accuracy: 0.7442 - val_loss: 1.0173 - val_accuracy: 0.6500
# Epoch 14/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5607 - accuracy: 0.7847 - val_loss: 0.9529 - val_accuracy: 0.6967
# Epoch 15/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5917 - accuracy: 0.7702 - val_loss: 1.0151 - val_accuracy: 0.6733
# Epoch 16/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5434 - accuracy: 0.7952 - val_loss: 1.1048 - val_accuracy: 0.6733
# Epoch 17/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5358 - accuracy: 0.8232 - val_loss: 1.0274 - val_accuracy: 0.6700
# Epoch 18/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4804 - accuracy: 0.8257 - val_loss: 1.0836 - val_accuracy: 0.6733
# Epoch 19/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.7940 - val_loss: 1.0596 - val_accuracy: 0.6233
# Epoch 20/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4501 - accuracy: 0.8316 - val_loss: 1.0957 - val_accuracy: 0.6133
# Epoch 21/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.8359 - val_loss: 1.0429 - val_accuracy: 0.6867
# Epoch 22/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4060 - accuracy: 0.8573 - val_loss: 1.1521 - val_accuracy: 0.6733
# Epoch 23/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4423 - accuracy: 0.8163 - val_loss: 1.1695 - val_accuracy: 0.7200
# Epoch 24/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4460 - accuracy: 0.8437 - val_loss: 1.2202 - val_accuracy: 0.7167
# Epoch 25/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3811 - accuracy: 0.8525 - val_loss: 1.0741 - val_accuracy: 0.6667
# Epoch 26/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8668 - val_loss: 1.0544 - val_accuracy: 0.7000
# Epoch 27/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3958 - accuracy: 0.8438 - val_loss: 1.0728 - val_accuracy: 0.7500
# Epoch 28/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3783 - accuracy: 0.8556 - val_loss: 1.1524 - val_accuracy: 0.7233
# Epoch 29/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.8932 - val_loss: 1.4147 - val_accuracy: 0.6600
# Epoch 30/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3198 - accuracy: 0.8841 - val_loss: 1.1434 - val_accuracy: 0.6700
# Epoch 31/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3458 - accuracy: 0.8758 - val_loss: 1.2327 - val_accuracy: 0.7133
# Epoch 32/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2761 - accuracy: 0.9014 - val_loss: 1.2581 - val_accuracy: 0.7067
# Epoch 33/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.3233 - accuracy: 0.8807 - val_loss: 1.2440 - val_accuracy: 0.6433
# Epoch 34/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.2533 - accuracy: 0.9150 - val_loss: 1.2309 - val_accuracy: 0.7467
# Epoch 35/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.8942 - val_loss: 1.4167 - val_accuracy: 0.6067
# Epoch 36/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2653 - accuracy: 0.9067 - val_loss: 1.2937 - val_accuracy: 0.6300
# Epoch 37/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.9146 - val_loss: 1.1926 - val_accuracy: 0.7167
# Epoch 38/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2355 - accuracy: 0.9229 - val_loss: 1.2905 - val_accuracy: 0.6900
# Epoch 39/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2388 - accuracy: 0.9046 - val_loss: 1.2570 - val_accuracy: 0.7000
# Epoch 40/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.9203 - val_loss: 1.1986 - val_accuracy: 0.6867
# Epoch 41/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1963 - accuracy: 0.9445 - val_loss: 1.2450 - val_accuracy: 0.7000
# Epoch 42/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9222 - val_loss: 1.6045 - val_accuracy: 0.5767
# Epoch 43/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.9110 - val_loss: 1.4857 - val_accuracy: 0.7167
# Epoch 44/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2405 - accuracy: 0.9206 - val_loss: 1.3997 - val_accuracy: 0.6800
# Epoch 45/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1832 - accuracy: 0.9347 - val_loss: 1.2597 - val_accuracy: 0.6933
# Epoch 46/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1725 - accuracy: 0.9448 - val_loss: 1.3419 - val_accuracy: 0.6633
# Epoch 47/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1767 - accuracy: 0.9413 - val_loss: 1.4381 - val_accuracy: 0.7100
# Epoch 48/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2103 - accuracy: 0.9167 - val_loss: 1.3516 - val_accuracy: 0.6600
# Epoch 49/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1733 - accuracy: 0.9435 - val_loss: 1.5074 - val_accuracy: 0.5933
# Epoch 50/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1820 - accuracy: 0.9321 - val_loss: 1.5984 - val_accuracy: 0.7167
# Epoch 51/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2016 - accuracy: 0.9249 - val_loss: 1.3722 - val_accuracy: 0.6767
# Epoch 52/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9181 - val_loss: 1.3640 - val_accuracy: 0.6800
# Epoch 53/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1770 - accuracy: 0.9332 - val_loss: 1.4682 - val_accuracy: 0.6333
# Epoch 54/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1685 - accuracy: 0.9481 - val_loss: 1.4120 - val_accuracy: 0.7000
# Epoch 55/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1795 - accuracy: 0.9291 - val_loss: 1.3864 - val_accuracy: 0.7000
# Epoch 56/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1613 - accuracy: 0.9459 - val_loss: 1.5846 - val_accuracy: 0.7267
# Epoch 57/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.9502 - val_loss: 1.4763 - val_accuracy: 0.7067
# Epoch 00057: early stopping

# %%
''' Visualize the training/validation loss and training/validation accuracy'''
rcParams['figure.figsize'] = 10, 7

loss = history_bn.history.get('loss')       # 取出訓練完成後loss的訓練數據
val_loss = history_bn.history.get('val_loss')   # 取出訓練完成後val_loss的訓練數據

acc = history_bn.history.get('accuracy')     # 取出訓練完成後accuracy的訓練數據
val_acc = history_bn.history.get('val_accuracy') # 取出訓練完成後val_accuracy的訓練數據

plt.figure(0)

plt.subplot(121)

# 個別繪出loss以及val_loss的線條
plt.plot(range(len(loss)), loss, label='Training Loss')
plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.legend(loc='best')
plt.title('Loss')


plt.subplot(122)
# 個別繪出accuracy以及val_accuracy的線條
plt.plot(range(len(acc)), acc, label='Training Accuracy')
plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.legend(loc='best')
plt.title('Accuracy')

plt.show()

# %%
#Batch Normalization + drop out
pred_bn = model_bn.evaluate(x_test, y_test, verbose=2)
# Out:
# 11/11 - 0s - loss: 1.5755 - accuracy: 0.6726

# %%
import pandas as pd

#取得模型預測結果
predict=model_bn.predict_classes(x_test)

#取得y_test未進行one-hot encoding的label資料
raw_test_label=[]
for y_onehot in y_test:
  raw_test_label.append(y_onehot.argmax())

pd.crosstab([raw_test_label], predict, rownames=['class'], colnames=['predict'])
# Out:
# predict   0    1  2   3   4
# class
# 0        32   12  0   2   0
# 1        20  141  2   9   4
# 2         2    8  7   0   3
# 3         2   23  2  14   3
# 4         0   10  0   8  32

# %%
from sklearn import metrics
print(metrics.classification_report(raw_test_label, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.70      0.63        46
#            1       0.73      0.80      0.76       176
#            2       0.64      0.35      0.45        20
#            3       0.42      0.32      0.36        44
#            4       0.76      0.64      0.70        50
#
#     accuracy                           0.67       336
#    macro avg       0.62      0.56      0.58       336
# weighted avg       0.67      0.67      0.66       336

# %% [markdown]
# # 關於Overfitting的一些看法

# %% [markdown]
# ![alt text](https://gitlab.aiacademy.tw/tclin/at091-DL/raw/master/pic/overfitting-2.png)

# %% [markdown]
# <hr/>

# %% [markdown]
# # **更多的實作範例,請參考官方文件**

# %% [markdown]
# **Tensorflow官網範例:** https://www.tensorflow.org/overview?hl=zh-tw

# %% [markdown]
# 例如:可以練習CNN模型的Cifar10影像分類實作 https://www.tensorflow.org/tutorials/images/cnn

# %% [markdown]
# **Keras官網範例:** https://keras.io/examples/

# %% [markdown]
# 例如:時間序列的異常偵測 https://keras.io/examples/timeseries/timeseries_anomaly_detection
