# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns       
from scipy import stats

import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline  
# 为了在jupyter notebook里作图，需要用到这个命令

# %% [markdown]
# ## Load train data and test data
# #### 並先刪除不必要的欄位

# %%
train = pd.read_csv("train.csv")
#train.drop("ID", axis = 1, inplace = True)
print (train.shape)
# 取出train data的y值
y_train=train['class']
print ("y_train:",y_train.shape)
train.drop(["ID","class"], axis = 1, inplace = True)
x_train=train
print ("x_train:",x_train.shape)
# Out:
# (7160, 184)
# y_train: (7160,)
# x_train: (7160, 182)

# %%
x_test = pd.read_csv("test.csv")
x_test_id=x_test["id"]
x_test.drop(["id"], axis = 1, inplace = True)
print ("x_test:",x_test.shape)
print (train.info())
# Out:
# x_test: (1791, 182)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7160 entries, 0 to 7159
# Columns: 182 entries, appearedTimeOfDay to cooc_151
# dtypes: bool(168), float64(6), int64(3), object(5)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ## 將train data和test data combine起來，後續一起做資料處理
# #### 如果分開做的話，做one-hot-encoding時可能會有feature數量不一致的問題

# %%
data=pd.concat([x_train,x_test],axis=0,ignore_index = False)
print (data.shape)
#紀錄train data的筆數,後續EDA完成後要再依此筆數拆分train data和test data
x_train_qty=x_train.shape[0]
# Out:
# (8951, 182)

# %% [markdown]
# ## 判斷fetures是屬於categorical or numerical

# %%
# Differentiate numerical features (minus the target) and categorical features
categorical_features = data.select_dtypes(include=['object']).columns
print(categorical_features)
numerical_features = data.select_dtypes(exclude = ["object"]).columns
print(numerical_features)
print("Categorical features : " + str(len(categorical_features)))
print("Numerical features : " + str(len(numerical_features)))
# Out:
# Index(['appearedTimeOfDay', 'city', 'continent', 'weather', 'weatherIcon'], dtype='object')
# Index(['appearedHour', 'appearedMinute', 'terrainType', 'closeToWater',
#        'temperature', 'windSpeed', 'pressure', 'population_density', 'urban',
#        'suburban',
#        ...
#        'cooc_142', 'cooc_143', 'cooc_144', 'cooc_145', 'cooc_146', 'cooc_147',
#        'cooc_148', 'cooc_149', 'cooc_150', 'cooc_151'],
#       dtype='object', length=177)
# Categorical features : 5
# Numerical features : 177

# %% [markdown]
# ## 檢查Features datatype

# %%
print(data.dtypes.unique())
print(len(data.select_dtypes(include=['O']).columns))
print(data.select_dtypes(include=['O']).columns)
# Out:
# [dtype('O') dtype('int64') dtype('bool') dtype('float64')]
# 5
# Index(['appearedTimeOfDay', 'city', 'continent', 'weather', 'weatherIcon'], dtype='object')

# %%
data.head()
# Out:
#   appearedTimeOfDay  appearedHour  appearedMinute  terrainType  closeToWater  \
# 0           evening            19              10           13         False
# 1             night             5              19           13          True
# 2           evening            19              46            0          True
# 3           morning            11              10            0          True
# 4           evening            18              32           13          True
#
#           city  continent       weather  temperature  windSpeed    ...     \
# 0      Bangkok       Asia         Clear         27.8       9.00    ...
# 1     New_York    America         Clear         26.1       8.70    ...
# 2     New_York    America         Clear         24.7      16.82    ...
# 3       Hobart  Australia         Clear         12.7      13.25    ...
# 4  Los_Angeles    America  PartlyCloudy         19.1       5.78    ...
#
#    cooc_142 cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0     False    False     False     False     False     False     False
# 1     False    False     False     False     False     False     False
# 2     False    False     False     False     False     False     False
# 3     False    False     False     False     False     False     False
# 4     False    False     False     False     False     False     False
#
#    cooc_149  cooc_150  cooc_151
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 182 columns]

# %%
data.describe()
# Out:
#        appearedHour  appearedMinute  terrainType  temperature    windSpeed  \
# count   8951.000000     8951.000000  8951.000000  8951.000000  8951.000000
# mean      10.654452       30.643168     9.720590    23.281008     7.510169
# std        7.152858       17.439499     4.941831     6.054764     4.617323
# min        0.000000        0.000000     0.000000     4.800000     0.000000
# 25%        4.000000       16.000000     7.000000    18.500000     3.920000
# 50%       10.000000       32.000000    13.000000    23.800000     6.630000
# 75%       17.000000       46.000000    13.000000    27.500000    10.010000
# max       23.000000       59.000000    16.000000    41.200000    56.130000
#
#           pressure  population_density  gymDistanceKm  pokestopDistanceKm
# count  8951.000000         8951.000000    8951.000000         8951.000000
# mean   1014.904328         1541.905140       2.987937            0.562947
# std       5.828866         2230.860698      46.908371            7.479374
# min     996.330000            0.000000       0.004516            0.000319
# 25%    1010.695000           69.585650       0.178437            0.050817
# 50%    1015.290000          635.549800       0.314365            0.132209
# 75%    1019.290000         1955.863600       0.577406            0.310317
# max    1034.170000        10000.000000    3859.424664          455.313099

# %% [markdown]
# ## 處理時間欄位

# %%
data['appearedtime'] = data['appearedHour']+(data['appearedMinute']/60)
#maxtime=data['appearedtime'].max()
maxtime=24
data['appearedtime'].head()
# Out:
# 0    19.166667
# 1     5.316667
# 2    19.766667
# 3    11.166667
# 4    18.533333
# Name: appearedtime, dtype: float64

# %%
data['appearedtime_sin'] = np.sin(2 * np.pi * data['appearedtime']/maxtime)
data['appearedtime_cos'] = np.cos(2 * np.pi * data['appearedtime']/maxtime)

# %%
ax = data.plot.scatter('appearedtime_sin', 'appearedtime_cos').set_aspect('equal')

# %% [markdown]
# ## 刪除不需要的features

# %%
# city已經可以區分地區,所以不需要continent
data = data.drop(['continent'], axis=1)
#與weather類似，所以移除weatherIcon
data = data.drop(['weatherIcon'], axis=1)
#data = data.drop(['weather'], axis=1)
data = data.drop(['appearedHour', 'appearedMinute','appearedtime'], axis=1)
# 時間欄位與appearedTimeOfDay效果相似,保留appearedTimeOfDay
#data = data.drop(['appearedTimeOfDay'], axis=1)
data = data.drop(['appearedtime_sin', 'appearedtime_cos'], axis=1)

# %% [markdown]
# ## 顯示數值欄位基本資訊

# %%
data.describe()
# Out:
#        terrainType  temperature    windSpeed     pressure  population_density  \
# count  8951.000000  8951.000000  8951.000000  8951.000000         8951.000000
# mean      9.720590    23.281008     7.510169  1014.904328         1541.905140
# std       4.941831     6.054764     4.617323     5.828866         2230.860698
# min       0.000000     4.800000     0.000000   996.330000            0.000000
# 25%       7.000000    18.500000     3.920000  1010.695000           69.585650
# 50%      13.000000    23.800000     6.630000  1015.290000          635.549800
# 75%      13.000000    27.500000    10.010000  1019.290000         1955.863600
# max      16.000000    41.200000    56.130000  1034.170000        10000.000000
#
#        gymDistanceKm  pokestopDistanceKm
# count    8951.000000         8951.000000
# mean        2.987937            0.562947
# std        46.908371            7.479374
# min         0.004516            0.000319
# 25%         0.178437            0.050817
# 50%         0.314365            0.132209
# 75%         0.577406            0.310317
# max      3859.424664          455.313099

# %% [markdown]
# ## 判斷是否有missing data

# %%
# Missing data in train
data_na = data.isnull().sum()
data_na = data_na[data_na>0]
data_na.sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 查看min為0的筆數是否異常

# %%
print (data.loc[(data['population_density']==0),'population_density'].count())
data.loc[(data['population_density']==0),'population_density'].count()/data.shape[0]
# Out:
# 1652
# 0.18456038431460173

# %% [markdown]
# ## 將數值為不應該為0的值改用平均值

# %%
# 使用該city的population_density平均值取代0值
for i in data['city'].unique():
    mean=data[data['city']==i].loc[:,'population_density'].mean()
    data.loc[(data['city']==i) & (data['population_density']==0),'population_density']=mean

# %%
data.head()
# Out:
#   appearedTimeOfDay  terrainType  closeToWater         city       weather  \
# 0           evening           13         False      Bangkok         Clear
# 1             night           13          True     New_York         Clear
# 2           evening            0          True     New_York         Clear
# 3           morning            0          True       Hobart         Clear
# 4           evening           13          True  Los_Angeles  PartlyCloudy
#
#    temperature  windSpeed  pressure  population_density  urban    ...     \
# 0         27.8       9.00   1008.96          6019.04440   True    ...
# 1         26.1       8.70   1018.96          1172.14576  False    ...
# 2         24.7      16.82   1023.22          1172.14576  False    ...
# 3         12.7      13.25   1014.19           128.89505  False    ...
# 4         19.1       5.78   1011.36          4188.39100   True    ...
#
#    cooc_142  cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0     False     False     False     False     False     False     False
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
#
#    cooc_149  cooc_150  cooc_151
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 178 columns]

# %%
data.describe()
# Out:
#        terrainType  temperature    windSpeed     pressure  population_density  \
# count  8951.000000  8951.000000  8951.000000  8951.000000         8951.000000
# mean      9.720590    23.281008     7.510169  1014.904328         1786.441753
# std       4.941831     6.054764     4.617323     5.828866         2143.401196
# min       0.000000     4.800000     0.000000   996.330000            0.000000
# 25%       7.000000    18.500000     3.920000  1010.695000          458.582340
# 50%      13.000000    23.800000     6.630000  1015.290000         1135.319600
# 75%      13.000000    27.500000    10.010000  1019.290000         2261.157000
# max      16.000000    41.200000    56.130000  1034.170000        10000.000000
#
#        gymDistanceKm  pokestopDistanceKm
# count    8951.000000         8951.000000
# mean        2.987937            0.562947
# std        46.908371            7.479374
# min         0.004516            0.000319
# 25%         0.178437            0.050817
# 50%         0.314365            0.132209
# 75%         0.577406            0.310317
# max      3859.424664          455.313099

# %% [markdown]
# ## 將以數值做分類型態的feature的資料型態轉換成字串，避免訓練時被當作數值處理
# #### 例terrainType是以0,1,2..來表示不同種類的地形，但並非數值，所以要做轉換

# %%
#data.terrainType = data.terrainType.astype( str )
features_to_str=["terrainType"]
data[features_to_str]=data[features_to_str].astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8951 entries, 0 to 1790
# Columns: 178 entries, appearedTimeOfDay to cooc_151
# dtypes: bool(168), float64(6), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# ## 對數值欄位做 normalization

# %%
from sklearn import preprocessing
# 前面已經取過一次numerical_features,但因為中間features有增減，所以再取一次
numerical_features = data.select_dtypes(exclude = ["object"]).columns
data[numerical_features] = preprocessing.scale(data[numerical_features])
print (data.head())
# Out:
#   appearedTimeOfDay terrainType  closeToWater         city       weather  \
# 0           evening          13     -0.901079      Bangkok         Clear
# 1             night          13      1.109781     New_York         Clear
# 2           evening           0      1.109781     New_York         Clear
# 3           morning           0      1.109781       Hobart         Clear
# 4           evening          13      1.109781  Los_Angeles  PartlyCloudy
#
#    temperature  windSpeed  pressure  population_density     urban    ...     \
# 0     0.746395   0.322679 -1.019866            1.974824  1.133395    ...
# 1     0.465609   0.257703  0.695830           -0.286615 -0.882305    ...
# 2     0.234373   2.016396  1.426716           -0.286615 -0.882305    ...
# 3    -1.747648   1.243178 -0.122557           -0.773369 -0.882305    ...
# 4    -0.690571  -0.374733 -0.608099            1.120688  1.133395    ...
#
#    cooc_142  cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 1  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 2  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 3  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 4  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
#
#    cooc_149  cooc_150  cooc_151
# 0 -0.021144       0.0       0.0
# 1 -0.021144       0.0       0.0
# 2 -0.021144       0.0       0.0
# 3 -0.021144       0.0       0.0
# 4 -0.021144       0.0       0.0
#
# [5 rows x 178 columns]

# %% [markdown]
# ## 對類別型features做one-hot-encoding
# #### 某一類別型feature有三個值，則會被轉換成三個features

# %%
data=pd.get_dummies(data)
data.shape
# Out:
# (8951, 292)

# %%
feture_qty=data.shape[1]
print (feture_qty)
# Out:
# 292

# %% [markdown]
# ## 將整理後的資料再拆成train data和test data

# %%
x_train=data[:x_train_qty]
x_test=data[x_train_qty:]
print (x_train.shape)
print (x_test.shape)
# Out:
# (7160, 292)
# (1791, 292)

# %% [markdown]
# ## 對train data y 做 one-hot-encoding

# %%
# one hot encoding

y_one_hot = np.zeros((len(y_train), 6))  
y_one_hot[np.arange(len(y_train)), y_train] = 1

print (y_one_hot.shape)
# Out:
# (7160, 6)

# %% [markdown]
# ## 設定訓練結果存放路徑

# %%
import os
model_path = os.path.join(os.getcwd(), 'model')
plt_path = os.path.join(os.getcwd(), 'plt')

#model_name = 'keras_adam_trained_model.h5'
if not os.path.isdir(model_path):
    os.makedirs(model_path)
if not os.path.isdir(plt_path):
    os.makedirs(plt_path)

#model_path_name = os.path.join(model_path, model_name)

# %% [markdown]
# # 用 keras 建 model

# %% [markdown]
# ## import keras library

# %%
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation
from keras.callbacks import ModelCheckpoint,EarlyStopping

# %% [markdown]
# ## 模型訓練參數設定
# 9/4 目前效果最佳的設定值
# model_dropout=0.4
# batch_size 128
# epochs = 300 #batch_size調大,epochs也要調大
# learning_rate = 0.001 #預設即為0.001。這case調大後效果不佳，調小效果也不明顯，所以使用預設值即可
# train_data_ratio = 0.85 # 調整稍有變化。0.85較佳
# es_patience=60

# %%
# model add parameter
model_dropout=0.4
# model fit parameter
batch_size_list=[128] #測試相同條件下，128最佳
#batch_size_list=[32,64,96,128,160,192,224,256] # 測試相同條件下，128最佳
epochs = 300 #batch_size調大,epochs也要調大
learning_rate = 0.001 #預設即為0.001。這case調大後效果不佳，調小效果也不明顯，所以使用預設值即可 
train_data_ratio = 0.9 # 調整稍有變化。0.85較佳 0.9 -> 0.61872

# check point parameter
cp_monitor='val_acc'

# early stop parameter
es_monitor='val_acc'
es_patience=60

# file
file_name_prefix="adam_"

# %%
def train_model(batch_size_in,verbose_in=1):
    #check point
    model_name = file_name_prefix + str(batch_size_in)
    plt_name_loss = file_name_prefix + str(batch_size_in) + "_loss"
    plt_name_acc = file_name_prefix + str(batch_size_in)
    model_path_name = os.path.join(model_path, model_name)
    checkpoint = ModelCheckpoint(model_path_name, monitor=cp_monitor, 
                             verbose=2, save_best_only=True, save_weights_only=False)
    #early stop
    earlystop = EarlyStopping(monitor=es_monitor, patience=es_patience, verbose=1)    
 

   #使用dropout無太大變化
    #使用2個隱藏層沒太大變化
    model = keras.Sequential()
    model.add(Dropout(model_dropout, input_shape=(feture_qty,)))
    model.add(Dense(200,activation='relu'))
        #model.add(Dense(128, activation='relu', input_shape=(feture_qty,)))
    model.add(Dropout(model_dropout))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(model_dropout))
    model.add(Dense(50, activation='relu')) #多這一層沒幫助
    model.add(Dropout(model_dropout))
    model.add(Dense(6, activation='softmax')) 

  #  print(model.summary())    
    opt=keras.optimizers.Adam(lr=learning_rate)
    #opt=keras.optimizers.SGD() #相同條件下，SGD valid accuracy 0.54562，相較Adam 0.60987差很多
    model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
    #此case加上"shuffle=False"效果比較好一點?
    model_history = model.fit(x=x_train, y=y_one_hot,
                          batch_size=batch_size_in,
                          epochs=epochs,
                          shuffle=False,
                          verbose=verbose_in,
                          validation_split=1 - train_data_ratio, callbacks=[checkpoint,earlystop])
    train_loss = model_history.history['loss']
    train_acc = model_history.history['acc']
    valid_loss = model_history.history['val_loss']
    valid_acc = model_history.history['val_acc']
   # valid_acc_max = model_history.history['val_acc']

    #print ("valid_acc_best",valid_acc_best)

    del model
    return train_loss,train_acc,valid_loss,valid_acc
    #return valid_acc

# %% [markdown]
# ## Create model

# %%
   
best_valid_acc=0
best_batch_size=0
for batch_size in batch_size_list:
    _,_,_,valid_acc=train_model(batch_size_in=batch_size,verbose_in=0)
    valid_acc_max=np.array(valid_acc).max()
    if valid_acc_max > best_valid_acc :
        best_valid_acc=valid_acc_max
        best_batch_size=batch_size
# Out:
# Epoch 00001: val_acc improved from -inf to 0.32542, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00002: val_acc improved from 0.32542 to 0.36592, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00003: val_acc improved from 0.36592 to 0.41341, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00004: val_acc improved from 0.41341 to 0.46788, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00005: val_acc improved from 0.46788 to 0.49022, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00006: val_acc improved from 0.49022 to 0.50559, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00007: val_acc improved from 0.50559 to 0.51397, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00008: val_acc improved from 0.51397 to 0.52374, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00009: val_acc did not improve from 0.52374
#
# Epoch 00010: val_acc improved from 0.52374 to 0.52933, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00011: val_acc did not improve from 0.52933
#
# Epoch 00012: val_acc did not improve from 0.52933
#
# Epoch 00013: val_acc did not improve from 0.52933
#
# Epoch 00014: val_acc did not improve from 0.52933
#
# Epoch 00015: val_acc improved from 0.52933 to 0.53073, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00016: val_acc did not improve from 0.53073
#
# Epoch 00017: val_acc improved from 0.53073 to 0.54888, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00018: val_acc did not improve from 0.54888
#
# Epoch 00019: val_acc did not improve from 0.54888
#
# Epoch 00020: val_acc did not improve from 0.54888
#
# Epoch 00021: val_acc did not improve from 0.54888
#
# Epoch 00022: val_acc improved from 0.54888 to 0.56006, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00023: val_acc did not improve from 0.56006
#
# Epoch 00024: val_acc did not improve from 0.56006
#
# Epoch 00025: val_acc improved from 0.56006 to 0.56564, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00026: val_acc improved from 0.56564 to 0.57682, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00027: val_acc did not improve from 0.57682
#
# Epoch 00028: val_acc did not improve from 0.57682
#
# Epoch 00029: val_acc did not improve from 0.57682
#
# Epoch 00030: val_acc did not improve from 0.57682
#
# Epoch 00031: val_acc did not improve from 0.57682
#
# Epoch 00032: val_acc did not improve from 0.57682
#
# Epoch 00033: val_acc did not improve from 0.57682
#
# Epoch 00034: val_acc improved from 0.57682 to 0.57821, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00035: val_acc did not improve from 0.57821
#
# Epoch 00036: val_acc did not improve from 0.57821
#
# Epoch 00037: val_acc improved from 0.57821 to 0.58659, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00038: val_acc did not improve from 0.58659
#
# Epoch 00039: val_acc did not improve from 0.58659
#
# Epoch 00040: val_acc did not improve from 0.58659
#
# Epoch 00041: val_acc did not improve from 0.58659
#
# Epoch 00042: val_acc improved from 0.58659 to 0.59358, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00043: val_acc did not improve from 0.59358
#
# Epoch 00044: val_acc did not improve from 0.59358
#
# Epoch 00045: val_acc improved from 0.59358 to 0.59497, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00046: val_acc did not improve from 0.59497
#
# Epoch 00047: val_acc did not improve from 0.59497
#
# Epoch 00048: val_acc did not improve from 0.59497
#
# Epoch 00049: val_acc did not improve from 0.59497
#
# Epoch 00050: val_acc did not improve from 0.59497
#
# Epoch 00051: val_acc did not improve from 0.59497
#
# Epoch 00052: val_acc did not improve from 0.59497
#
# Epoch 00053: val_acc did not improve from 0.59497
#
# Epoch 00054: val_acc did not improve from 0.59497
#
# Epoch 00055: val_acc did not improve from 0.59497
#
# Epoch 00056: val_acc did not improve from 0.59497
#
# Epoch 00057: val_acc did not improve from 0.59497
#
# Epoch 00058: val_acc did not improve from 0.59497
#
# Epoch 00059: val_acc did not improve from 0.59497
#
# Epoch 00060: val_acc did not improve from 0.59497
#
# Epoch 00061: val_acc did not improve from 0.59497
#
# Epoch 00062: val_acc did not improve from 0.59497
#
# Epoch 00063: val_acc did not improve from 0.59497
#
# Epoch 00064: val_acc did not improve from 0.59497
#
# Epoch 00065: val_acc did not improve from 0.59497
#
# Epoch 00066: val_acc did not improve from 0.59497
#
# Epoch 00067: val_acc did not improve from 0.59497
#
# Epoch 00068: val_acc did not improve from 0.59497
#
# Epoch 00069: val_acc did not improve from 0.59497
#
# Epoch 00070: val_acc did not improve from 0.59497
#
# Epoch 00071: val_acc did not improve from 0.59497
#
# Epoch 00072: val_acc did not improve from 0.59497
#
# Epoch 00073: val_acc did not improve from 0.59497
#
# Epoch 00074: val_acc did not improve from 0.59497
#
# Epoch 00075: val_acc improved from 0.59497 to 0.60056, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00076: val_acc did not improve from 0.60056
#
# Epoch 00077: val_acc did not improve from 0.60056
#
# Epoch 00078: val_acc did not improve from 0.60056
#
# Epoch 00079: val_acc did not improve from 0.60056
#
# Epoch 00080: val_acc did not improve from 0.60056
#
# Epoch 00081: val_acc did not improve from 0.60056
#
# Epoch 00082: val_acc improved from 0.60056 to 0.60056, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00083: val_acc did not improve from 0.60056
#
# Epoch 00084: val_acc did not improve from 0.60056
#
# Epoch 00085: val_acc did not improve from 0.60056
#
# Epoch 00086: val_acc improved from 0.60056 to 0.60335, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00087: val_acc did not improve from 0.60335
#
# Epoch 00088: val_acc did not improve from 0.60335
#
# Epoch 00089: val_acc did not improve from 0.60335
#
# Epoch 00090: val_acc did not improve from 0.60335
#
# Epoch 00091: val_acc did not improve from 0.60335
#
# Epoch 00092: val_acc improved from 0.60335 to 0.60475, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00093: val_acc did not improve from 0.60475
#
# Epoch 00094: val_acc did not improve from 0.60475
#
# Epoch 00095: val_acc did not improve from 0.60475
#
# Epoch 00096: val_acc did not improve from 0.60475
#
# Epoch 00097: val_acc did not improve from 0.60475
#
# Epoch 00098: val_acc did not improve from 0.60475
#
# Epoch 00099: val_acc did not improve from 0.60475
#
# Epoch 00100: val_acc did not improve from 0.60475
#
# Epoch 00101: val_acc did not improve from 0.60475
#
# Epoch 00102: val_acc did not improve from 0.60475
#
# Epoch 00103: val_acc did not improve from 0.60475
#
# Epoch 00104: val_acc did not improve from 0.60475
#
# Epoch 00105: val_acc did not improve from 0.60475
#
# Epoch 00106: val_acc did not improve from 0.60475
#
# Epoch 00107: val_acc did not improve from 0.60475
#
# Epoch 00108: val_acc did not improve from 0.60475
#
# Epoch 00109: val_acc did not improve from 0.60475
#
# Epoch 00110: val_acc did not improve from 0.60475
#
# Epoch 00111: val_acc did not improve from 0.60475
#
# Epoch 00112: val_acc did not improve from 0.60475
#
# Epoch 00113: val_acc did not improve from 0.60475
#
# Epoch 00114: val_acc did not improve from 0.60475
#
# Epoch 00115: val_acc did not improve from 0.60475
#
# Epoch 00116: val_acc did not improve from 0.60475
#
# Epoch 00117: val_acc did not improve from 0.60475
#
# Epoch 00118: val_acc did not improve from 0.60475
#
# Epoch 00119: val_acc did not improve from 0.60475
#
# Epoch 00120: val_acc did not improve from 0.60475
#
# Epoch 00121: val_acc did not improve from 0.60475
#
# Epoch 00122: val_acc did not improve from 0.60475
#
# Epoch 00123: val_acc did not improve from 0.60475
#
# Epoch 00124: val_acc did not improve from 0.60475
#
# Epoch 00125: val_acc did not improve from 0.60475
#
# Epoch 00126: val_acc did not improve from 0.60475
#
# Epoch 00127: val_acc did not improve from 0.60475
#
# Epoch 00128: val_acc did not improve from 0.60475
#
# Epoch 00129: val_acc did not improve from 0.60475
#
# Epoch 00130: val_acc did not improve from 0.60475
#
# Epoch 00131: val_acc did not improve from 0.60475
#
# Epoch 00132: val_acc did not improve from 0.60475
#
# Epoch 00133: val_acc did not improve from 0.60475
#
# Epoch 00134: val_acc did not improve from 0.60475
#
# Epoch 00135: val_acc did not improve from 0.60475
#
# Epoch 00136: val_acc improved from 0.60475 to 0.60615, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00137: val_acc did not improve from 0.60615
#
# Epoch 00138: val_acc did not improve from 0.60615
#
# Epoch 00139: val_acc did not improve from 0.60615
#
# Epoch 00140: val_acc did not improve from 0.60615
#
# Epoch 00141: val_acc improved from 0.60615 to 0.60754, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00142: val_acc did not improve from 0.60754
#
# Epoch 00143: val_acc improved from 0.60754 to 0.61173, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00144: val_acc improved from 0.61173 to 0.61592, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00145: val_acc did not improve from 0.61592
#
# Epoch 00146: val_acc did not improve from 0.61592
#
# Epoch 00147: val_acc did not improve from 0.61592
#
# Epoch 00148: val_acc did not improve from 0.61592
#
# Epoch 00149: val_acc did not improve from 0.61592
#
# Epoch 00150: val_acc did not improve from 0.61592
#
# Epoch 00151: val_acc did not improve from 0.61592
#
# Epoch 00152: val_acc did not improve from 0.61592
#
# Epoch 00153: val_acc did not improve from 0.61592
#
# Epoch 00154: val_acc did not improve from 0.61592
#
# Epoch 00155: val_acc did not improve from 0.61592
#
# Epoch 00156: val_acc did not improve from 0.61592
#
# Epoch 00157: val_acc did not improve from 0.61592
#
# Epoch 00158: val_acc did not improve from 0.61592
#
# Epoch 00159: val_acc did not improve from 0.61592
#
# Epoch 00160: val_acc improved from 0.61592 to 0.61732, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00161: val_acc did not improve from 0.61732
#
# Epoch 00162: val_acc did not improve from 0.61732
#
# Epoch 00163: val_acc did not improve from 0.61732
#
# Epoch 00164: val_acc did not improve from 0.61732
#
# Epoch 00165: val_acc did not improve from 0.61732
#
# Epoch 00166: val_acc did not improve from 0.61732
#
# Epoch 00167: val_acc did not improve from 0.61732
#
# Epoch 00168: val_acc did not improve from 0.61732
#
# Epoch 00169: val_acc did not improve from 0.61732
#
# Epoch 00170: val_acc did not improve from 0.61732
#
# Epoch 00171: val_acc improved from 0.61732 to 0.62011, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_128
#
# Epoch 00172: val_acc did not improve from 0.62011
#
# Epoch 00173: val_acc did not improve from 0.62011
#
# Epoch 00174: val_acc did not improve from 0.62011
#
# Epoch 00175: val_acc did not improve from 0.62011
#
# Epoch 00176: val_acc did not improve from 0.62011
#
# Epoch 00177: val_acc did not improve from 0.62011
#
# Epoch 00178: val_acc did not improve from 0.62011
#
# Epoch 00179: val_acc did not improve from 0.62011
#
# Epoch 00180: val_acc did not improve from 0.62011
#
# Epoch 00181: val_acc did not improve from 0.62011
#
# Epoch 00182: val_acc did not improve from 0.62011
#
# Epoch 00183: val_acc did not improve from 0.62011
#
# Epoch 00184: val_acc did not improve from 0.62011
#
# Epoch 00185: val_acc did not improve from 0.62011
#
# Epoch 00186: val_acc did not improve from 0.62011
#
# Epoch 00187: val_acc did not improve from 0.62011
#
# Epoch 00188: val_acc did not improve from 0.62011
#
# Epoch 00189: val_acc did not improve from 0.62011
#
# Epoch 00190: val_acc did not improve from 0.62011
#
# Epoch 00191: val_acc did not improve from 0.62011
#
# Epoch 00192: val_acc did not improve from 0.62011
#
# Epoch 00193: val_acc did not improve from 0.62011
#
# Epoch 00194: val_acc did not improve from 0.62011
#
# Epoch 00195: val_acc did not improve from 0.62011
#
# Epoch 00196: val_acc did not improve from 0.62011
#
# Epoch 00197: val_acc did not improve from 0.62011
#
# Epoch 00198: val_acc did not improve from 0.62011
#
# Epoch 00199: val_acc did not improve from 0.62011
#
# Epoch 00200: val_acc did not improve from 0.62011
#
# Epoch 00201: val_acc did not improve from 0.62011
#
# Epoch 00202: val_acc did not improve from 0.62011
#
# Epoch 00203: val_acc did not improve from 0.62011
#
# Epoch 00204: val_acc did not improve from 0.62011
#
# Epoch 00205: val_acc did not improve from 0.62011
#
# Epoch 00206: val_acc did not improve from 0.62011
#
# Epoch 00207: val_acc did not improve from 0.62011
#
# Epoch 00208: val_acc did not improve from 0.62011
#
# Epoch 00209: val_acc did not improve from 0.62011
#
# Epoch 00210: val_acc did not improve from 0.62011
#
# Epoch 00211: val_acc did not improve from 0.62011
#
# Epoch 00212: val_acc did not improve from 0.62011
#
# Epoch 00213: val_acc did not improve from 0.62011
#
# Epoch 00214: val_acc did not improve from 0.62011
#
# Epoch 00215: val_acc did not improve from 0.62011
#
# Epoch 00216: val_acc did not improve from 0.62011
#
# Epoch 00217: val_acc did not improve from 0.62011
#
# Epoch 00218: val_acc did not improve from 0.62011
#
# Epoch 00219: val_acc did not improve from 0.62011
#
# Epoch 00220: val_acc did not improve from 0.62011
#
# Epoch 00221: val_acc did not improve from 0.62011
#
# Epoch 00222: val_acc did not improve from 0.62011
#
# Epoch 00223: val_acc did not improve from 0.62011
#
# Epoch 00224: val_acc did not improve from 0.62011
#
# Epoch 00225: val_acc did not improve from 0.62011
#
# Epoch 00226: val_acc did not improve from 0.62011
#
# Epoch 00227: val_acc did not improve from 0.62011
#
# Epoch 00228: val_acc did not improve from 0.62011
#
# Epoch 00229: val_acc did not improve from 0.62011
#
# Epoch 00230: val_acc did not improve from 0.62011
#
# Epoch 00231: val_acc did not improve from 0.62011
# Epoch 00231: early stopping

# %%
print (best_batch_size)
print (best_valid_acc)
best_model_path_name = os.path.join(model_path, 'adam_' + str(best_batch_size))
print (best_model_path_name)
# Out:
# 64
# 0.621508380221255
# /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64

# %%
#best_batch_size=160
train_loss,train_acc,valid_loss,valid_acc=train_model(batch_size_in=best_batch_size,verbose_in=1)
# Out:
# Train on 6444 samples, validate on 716 samples
# Epoch 1/300
# 6444/6444 [==============================] - 2s 279us/step - loss: 1.8259 - acc: 0.2351 - val_loss: 1.6529 - val_acc: 0.3841
#
# Epoch 00001: val_acc improved from -inf to 0.38408, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 2/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.6680 - acc: 0.3178 - val_loss: 1.5117 - val_acc: 0.4441
#
# Epoch 00002: val_acc improved from 0.38408 to 0.44413, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 3/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.5653 - acc: 0.3773 - val_loss: 1.3930 - val_acc: 0.5182
#
# Epoch 00003: val_acc improved from 0.44413 to 0.51816, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 4/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.5100 - acc: 0.3928 - val_loss: 1.3264 - val_acc: 0.5251
#
# Epoch 00004: val_acc improved from 0.51816 to 0.52514, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 5/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.4972 - acc: 0.4204 - val_loss: 1.2973 - val_acc: 0.5377
#
# Epoch 00005: val_acc improved from 0.52514 to 0.53771, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 6/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.4502 - acc: 0.4295 - val_loss: 1.2684 - val_acc: 0.5265
#
# Epoch 00006: val_acc did not improve from 0.53771
# Epoch 7/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.4271 - acc: 0.4418 - val_loss: 1.2648 - val_acc: 0.5251
#
# Epoch 00007: val_acc did not improve from 0.53771
# Epoch 8/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.4235 - acc: 0.4452 - val_loss: 1.2546 - val_acc: 0.5265
#
# Epoch 00008: val_acc did not improve from 0.53771
# Epoch 9/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3995 - acc: 0.4573 - val_loss: 1.2413 - val_acc: 0.5377
#
# Epoch 00009: val_acc did not improve from 0.53771
# Epoch 10/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3911 - acc: 0.4598 - val_loss: 1.2395 - val_acc: 0.5405
#
# Epoch 00010: val_acc improved from 0.53771 to 0.54050, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 11/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3901 - acc: 0.4597 - val_loss: 1.2405 - val_acc: 0.5419
#
# Epoch 00011: val_acc improved from 0.54050 to 0.54190, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 12/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3738 - acc: 0.4638 - val_loss: 1.2271 - val_acc: 0.5531
#
# Epoch 00012: val_acc improved from 0.54190 to 0.55307, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 13/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3640 - acc: 0.4690 - val_loss: 1.2137 - val_acc: 0.5475
#
# Epoch 00013: val_acc did not improve from 0.55307
# Epoch 14/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3835 - acc: 0.4694 - val_loss: 1.2176 - val_acc: 0.5391
#
# Epoch 00014: val_acc did not improve from 0.55307
# Epoch 15/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3544 - acc: 0.4738 - val_loss: 1.2165 - val_acc: 0.5307
#
# Epoch 00015: val_acc did not improve from 0.55307
# Epoch 16/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3521 - acc: 0.4859 - val_loss: 1.2075 - val_acc: 0.5656
#
# Epoch 00016: val_acc improved from 0.55307 to 0.56564, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 17/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3476 - acc: 0.4808 - val_loss: 1.2005 - val_acc: 0.5489
#
# Epoch 00017: val_acc did not improve from 0.56564
# Epoch 18/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3267 - acc: 0.4848 - val_loss: 1.2004 - val_acc: 0.5503
#
# Epoch 00018: val_acc did not improve from 0.56564
# Epoch 19/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3309 - acc: 0.4885 - val_loss: 1.1894 - val_acc: 0.5503
#
# Epoch 00019: val_acc did not improve from 0.56564
# Epoch 20/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3303 - acc: 0.4820 - val_loss: 1.1882 - val_acc: 0.5615
#
# Epoch 00020: val_acc did not improve from 0.56564
# Epoch 21/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3172 - acc: 0.4873 - val_loss: 1.1772 - val_acc: 0.5684
#
# Epoch 00021: val_acc improved from 0.56564 to 0.56844, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 22/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3238 - acc: 0.4896 - val_loss: 1.1902 - val_acc: 0.5670
#
# Epoch 00022: val_acc did not improve from 0.56844
# Epoch 23/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3231 - acc: 0.4927 - val_loss: 1.1913 - val_acc: 0.5684
#
# Epoch 00023: val_acc did not improve from 0.56844
# Epoch 24/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3127 - acc: 0.4957 - val_loss: 1.1885 - val_acc: 0.5684
#
# Epoch 00024: val_acc did not improve from 0.56844
# Epoch 25/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3218 - acc: 0.4891 - val_loss: 1.1827 - val_acc: 0.5642
#
# Epoch 00025: val_acc did not improve from 0.56844
# Epoch 26/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.3167 - acc: 0.4986 - val_loss: 1.1800 - val_acc: 0.5656
#
# Epoch 00026: val_acc did not improve from 0.56844
# Epoch 27/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.3058 - acc: 0.5017 - val_loss: 1.1776 - val_acc: 0.5754
#
# Epoch 00027: val_acc improved from 0.56844 to 0.57542, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 28/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2942 - acc: 0.5029 - val_loss: 1.1747 - val_acc: 0.5712
#
# Epoch 00028: val_acc did not improve from 0.57542
# Epoch 29/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2951 - acc: 0.4967 - val_loss: 1.1727 - val_acc: 0.5754
#
# Epoch 00029: val_acc did not improve from 0.57542
# Epoch 30/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2979 - acc: 0.5056 - val_loss: 1.1676 - val_acc: 0.5796
#
# Epoch 00030: val_acc improved from 0.57542 to 0.57961, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 31/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2889 - acc: 0.5005 - val_loss: 1.1689 - val_acc: 0.5698
#
# Epoch 00031: val_acc did not improve from 0.57961
# Epoch 32/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2885 - acc: 0.5093 - val_loss: 1.1647 - val_acc: 0.5810
#
# Epoch 00032: val_acc improved from 0.57961 to 0.58101, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 33/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2745 - acc: 0.5092 - val_loss: 1.1675 - val_acc: 0.5782
#
# Epoch 00033: val_acc did not improve from 0.58101
# Epoch 34/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2963 - acc: 0.5053 - val_loss: 1.1689 - val_acc: 0.5782
#
# Epoch 00034: val_acc did not improve from 0.58101
# Epoch 35/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2920 - acc: 0.5118 - val_loss: 1.1656 - val_acc: 0.5768
#
# Epoch 00035: val_acc did not improve from 0.58101
# Epoch 36/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2779 - acc: 0.5115 - val_loss: 1.1606 - val_acc: 0.5852
#
# Epoch 00036: val_acc improved from 0.58101 to 0.58520, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 37/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2821 - acc: 0.5092 - val_loss: 1.1666 - val_acc: 0.5656
#
# Epoch 00037: val_acc did not improve from 0.58520
# Epoch 38/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2787 - acc: 0.5085 - val_loss: 1.1677 - val_acc: 0.5712
#
# Epoch 00038: val_acc did not improve from 0.58520
# Epoch 39/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2627 - acc: 0.5213 - val_loss: 1.1642 - val_acc: 0.5740
#
# Epoch 00039: val_acc did not improve from 0.58520
# Epoch 40/300
# 6444/6444 [==============================] - 0s 54us/step - loss: 1.2784 - acc: 0.5160 - val_loss: 1.1620 - val_acc: 0.5810
#
# Epoch 00040: val_acc did not improve from 0.58520
# Epoch 41/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2685 - acc: 0.5144 - val_loss: 1.1642 - val_acc: 0.5810
#
# Epoch 00041: val_acc did not improve from 0.58520
# Epoch 42/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2499 - acc: 0.5157 - val_loss: 1.1553 - val_acc: 0.5810
#
# Epoch 00042: val_acc did not improve from 0.58520
# Epoch 43/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2771 - acc: 0.5138 - val_loss: 1.1629 - val_acc: 0.5796
#
# Epoch 00043: val_acc did not improve from 0.58520
# Epoch 44/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2616 - acc: 0.5191 - val_loss: 1.1524 - val_acc: 0.5824
#
# Epoch 00044: val_acc did not improve from 0.58520
# Epoch 45/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2450 - acc: 0.5231 - val_loss: 1.1598 - val_acc: 0.5768
#
# Epoch 00045: val_acc did not improve from 0.58520
# Epoch 46/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2605 - acc: 0.5171 - val_loss: 1.1566 - val_acc: 0.5838
#
# Epoch 00046: val_acc did not improve from 0.58520
# Epoch 47/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2702 - acc: 0.5048 - val_loss: 1.1624 - val_acc: 0.5866
#
# Epoch 00047: val_acc improved from 0.58520 to 0.58659, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 48/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2360 - acc: 0.5275 - val_loss: 1.1407 - val_acc: 0.5950
#
# Epoch 00048: val_acc improved from 0.58659 to 0.59497, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 49/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2397 - acc: 0.5188 - val_loss: 1.1519 - val_acc: 0.5824
#
# Epoch 00049: val_acc did not improve from 0.59497
# Epoch 50/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2426 - acc: 0.5276 - val_loss: 1.1586 - val_acc: 0.5880
#
# Epoch 00050: val_acc did not improve from 0.59497
# Epoch 51/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2487 - acc: 0.5216 - val_loss: 1.1598 - val_acc: 0.5866
#
# Epoch 00051: val_acc did not improve from 0.59497
# Epoch 52/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2535 - acc: 0.5231 - val_loss: 1.1556 - val_acc: 0.5880
#
# Epoch 00052: val_acc did not improve from 0.59497
# Epoch 53/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2490 - acc: 0.5163 - val_loss: 1.1565 - val_acc: 0.5908
#
# Epoch 00053: val_acc did not improve from 0.59497
# Epoch 54/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2384 - acc: 0.5220 - val_loss: 1.1501 - val_acc: 0.5880
#
# Epoch 00054: val_acc did not improve from 0.59497
# Epoch 55/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2515 - acc: 0.5317 - val_loss: 1.1415 - val_acc: 0.5908
#
# Epoch 00055: val_acc did not improve from 0.59497
# Epoch 56/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2512 - acc: 0.5245 - val_loss: 1.1405 - val_acc: 0.5908
#
# Epoch 00056: val_acc did not improve from 0.59497
# Epoch 57/300
# 6444/6444 [==============================] - 0s 54us/step - loss: 1.2330 - acc: 0.5250 - val_loss: 1.1422 - val_acc: 0.6047
#
# Epoch 00057: val_acc improved from 0.59497 to 0.60475, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 58/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2391 - acc: 0.5248 - val_loss: 1.1487 - val_acc: 0.5880
#
# Epoch 00058: val_acc did not improve from 0.60475
# Epoch 59/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2434 - acc: 0.5259 - val_loss: 1.1509 - val_acc: 0.6034
#
# Epoch 00059: val_acc did not improve from 0.60475
# Epoch 60/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2331 - acc: 0.5315 - val_loss: 1.1466 - val_acc: 0.5894
#
# Epoch 00060: val_acc did not improve from 0.60475
# Epoch 61/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2341 - acc: 0.5256 - val_loss: 1.1395 - val_acc: 0.5908
#
# Epoch 00061: val_acc did not improve from 0.60475
# Epoch 62/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2418 - acc: 0.5331 - val_loss: 1.1525 - val_acc: 0.6047
#
# Epoch 00062: val_acc did not improve from 0.60475
# Epoch 63/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2391 - acc: 0.5303 - val_loss: 1.1487 - val_acc: 0.5880
#
# Epoch 00063: val_acc did not improve from 0.60475
# Epoch 64/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2327 - acc: 0.5292 - val_loss: 1.1436 - val_acc: 0.6006
#
# Epoch 00064: val_acc did not improve from 0.60475
# Epoch 65/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2421 - acc: 0.5220 - val_loss: 1.1485 - val_acc: 0.6020
#
# Epoch 00065: val_acc did not improve from 0.60475
# Epoch 66/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2330 - acc: 0.5313 - val_loss: 1.1492 - val_acc: 0.5978
#
# Epoch 00066: val_acc did not improve from 0.60475
# Epoch 67/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2346 - acc: 0.5290 - val_loss: 1.1399 - val_acc: 0.5992
#
# Epoch 00067: val_acc did not improve from 0.60475
# Epoch 68/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2324 - acc: 0.5377 - val_loss: 1.1494 - val_acc: 0.5936
#
# Epoch 00068: val_acc did not improve from 0.60475
# Epoch 69/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2210 - acc: 0.5365 - val_loss: 1.1474 - val_acc: 0.6020
#
# Epoch 00069: val_acc did not improve from 0.60475
# Epoch 70/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2253 - acc: 0.5307 - val_loss: 1.1510 - val_acc: 0.5964
#
# Epoch 00070: val_acc did not improve from 0.60475
# Epoch 71/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2147 - acc: 0.5327 - val_loss: 1.1452 - val_acc: 0.6034
#
# Epoch 00071: val_acc did not improve from 0.60475
# Epoch 72/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2253 - acc: 0.5357 - val_loss: 1.1534 - val_acc: 0.5908
#
# Epoch 00072: val_acc did not improve from 0.60475
# Epoch 73/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2104 - acc: 0.5405 - val_loss: 1.1436 - val_acc: 0.6075
#
# Epoch 00073: val_acc improved from 0.60475 to 0.60754, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 74/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2043 - acc: 0.5410 - val_loss: 1.1565 - val_acc: 0.5880
#
# Epoch 00074: val_acc did not improve from 0.60754
# Epoch 75/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2189 - acc: 0.5329 - val_loss: 1.1573 - val_acc: 0.5978
#
# Epoch 00075: val_acc did not improve from 0.60754
# Epoch 76/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2005 - acc: 0.5383 - val_loss: 1.1463 - val_acc: 0.5992
#
# Epoch 00076: val_acc did not improve from 0.60754
# Epoch 77/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2247 - acc: 0.5393 - val_loss: 1.1475 - val_acc: 0.5894
#
# Epoch 00077: val_acc did not improve from 0.60754
# Epoch 78/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2213 - acc: 0.5371 - val_loss: 1.1548 - val_acc: 0.5880
#
# Epoch 00078: val_acc did not improve from 0.60754
# Epoch 79/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2223 - acc: 0.5337 - val_loss: 1.1583 - val_acc: 0.6034
#
# Epoch 00079: val_acc did not improve from 0.60754
# Epoch 80/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2236 - acc: 0.5357 - val_loss: 1.1529 - val_acc: 0.5908
#
# Epoch 00080: val_acc did not improve from 0.60754
# Epoch 81/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2190 - acc: 0.5358 - val_loss: 1.1508 - val_acc: 0.5964
#
# Epoch 00081: val_acc did not improve from 0.60754
# Epoch 82/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2033 - acc: 0.5377 - val_loss: 1.1471 - val_acc: 0.5964
#
# Epoch 00082: val_acc did not improve from 0.60754
# Epoch 83/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2253 - acc: 0.5317 - val_loss: 1.1462 - val_acc: 0.5908
#
# Epoch 00083: val_acc did not improve from 0.60754
# Epoch 84/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2181 - acc: 0.5343 - val_loss: 1.1420 - val_acc: 0.5964
#
# Epoch 00084: val_acc did not improve from 0.60754
# Epoch 85/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2010 - acc: 0.5403 - val_loss: 1.1428 - val_acc: 0.5978
#
# Epoch 00085: val_acc did not improve from 0.60754
# Epoch 86/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1984 - acc: 0.5486 - val_loss: 1.1425 - val_acc: 0.5894
#
# Epoch 00086: val_acc did not improve from 0.60754
# Epoch 87/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2132 - acc: 0.5304 - val_loss: 1.1375 - val_acc: 0.6020
#
# Epoch 00087: val_acc did not improve from 0.60754
# Epoch 88/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.2011 - acc: 0.5435 - val_loss: 1.1446 - val_acc: 0.6089
#
# Epoch 00088: val_acc improved from 0.60754 to 0.60894, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 89/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1990 - acc: 0.5447 - val_loss: 1.1493 - val_acc: 0.5964
#
# Epoch 00089: val_acc did not improve from 0.60894
# Epoch 90/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1967 - acc: 0.5475 - val_loss: 1.1468 - val_acc: 0.5964
#
# Epoch 00090: val_acc did not improve from 0.60894
# Epoch 91/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1989 - acc: 0.5445 - val_loss: 1.1379 - val_acc: 0.5978
#
# Epoch 00091: val_acc did not improve from 0.60894
# Epoch 92/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2153 - acc: 0.5351 - val_loss: 1.1454 - val_acc: 0.5922
#
# Epoch 00092: val_acc did not improve from 0.60894
# Epoch 93/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1998 - acc: 0.5436 - val_loss: 1.1442 - val_acc: 0.6075
#
# Epoch 00093: val_acc did not improve from 0.60894
# Epoch 94/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1957 - acc: 0.5483 - val_loss: 1.1434 - val_acc: 0.6131
#
# Epoch 00094: val_acc improved from 0.60894 to 0.61313, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 95/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1852 - acc: 0.5504 - val_loss: 1.1432 - val_acc: 0.6034
#
# Epoch 00095: val_acc did not improve from 0.61313
# Epoch 96/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1977 - acc: 0.5341 - val_loss: 1.1531 - val_acc: 0.5978
#
# Epoch 00096: val_acc did not improve from 0.61313
# Epoch 97/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1970 - acc: 0.5456 - val_loss: 1.1549 - val_acc: 0.6006
#
# Epoch 00097: val_acc did not improve from 0.61313
# Epoch 98/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1780 - acc: 0.5531 - val_loss: 1.1495 - val_acc: 0.5950
#
# Epoch 00098: val_acc did not improve from 0.61313
# Epoch 99/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1920 - acc: 0.5416 - val_loss: 1.1471 - val_acc: 0.5936
#
# Epoch 00099: val_acc did not improve from 0.61313
# Epoch 100/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1924 - acc: 0.5459 - val_loss: 1.1461 - val_acc: 0.6020
#
# Epoch 00100: val_acc did not improve from 0.61313
# Epoch 101/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2027 - acc: 0.5345 - val_loss: 1.1496 - val_acc: 0.5950
#
# Epoch 00101: val_acc did not improve from 0.61313
# Epoch 102/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1935 - acc: 0.5464 - val_loss: 1.1502 - val_acc: 0.5936
#
# Epoch 00102: val_acc did not improve from 0.61313
# Epoch 103/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1956 - acc: 0.5435 - val_loss: 1.1517 - val_acc: 0.5880
#
# Epoch 00103: val_acc did not improve from 0.61313
# Epoch 104/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1821 - acc: 0.5568 - val_loss: 1.1471 - val_acc: 0.6034
#
# Epoch 00104: val_acc did not improve from 0.61313
# Epoch 105/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1954 - acc: 0.5489 - val_loss: 1.1447 - val_acc: 0.6006
#
# Epoch 00105: val_acc did not improve from 0.61313
# Epoch 106/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1836 - acc: 0.5480 - val_loss: 1.1446 - val_acc: 0.6006
#
# Epoch 00106: val_acc did not improve from 0.61313
# Epoch 107/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1857 - acc: 0.5475 - val_loss: 1.1420 - val_acc: 0.6006
#
# Epoch 00107: val_acc did not improve from 0.61313
# Epoch 108/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1994 - acc: 0.5484 - val_loss: 1.1450 - val_acc: 0.5936
#
# Epoch 00108: val_acc did not improve from 0.61313
# Epoch 109/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1886 - acc: 0.5495 - val_loss: 1.1494 - val_acc: 0.5964
#
# Epoch 00109: val_acc did not improve from 0.61313
# Epoch 110/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1890 - acc: 0.5509 - val_loss: 1.1475 - val_acc: 0.5894
#
# Epoch 00110: val_acc did not improve from 0.61313
# Epoch 111/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1919 - acc: 0.5469 - val_loss: 1.1548 - val_acc: 0.6034
#
# Epoch 00111: val_acc did not improve from 0.61313
# Epoch 112/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1833 - acc: 0.5511 - val_loss: 1.1523 - val_acc: 0.5978
#
# Epoch 00112: val_acc did not improve from 0.61313
# Epoch 113/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2123 - acc: 0.5369 - val_loss: 1.1533 - val_acc: 0.5922
#
# Epoch 00113: val_acc did not improve from 0.61313
# Epoch 114/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1851 - acc: 0.5486 - val_loss: 1.1425 - val_acc: 0.6006
#
# Epoch 00114: val_acc did not improve from 0.61313
# Epoch 115/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1842 - acc: 0.5430 - val_loss: 1.1417 - val_acc: 0.6006
#
# Epoch 00115: val_acc did not improve from 0.61313
# Epoch 116/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1951 - acc: 0.5458 - val_loss: 1.1429 - val_acc: 0.6006
#
# Epoch 00116: val_acc did not improve from 0.61313
# Epoch 117/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1769 - acc: 0.5427 - val_loss: 1.1344 - val_acc: 0.5992
#
# Epoch 00117: val_acc did not improve from 0.61313
# Epoch 118/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.2025 - acc: 0.5448 - val_loss: 1.1409 - val_acc: 0.5922
#
# Epoch 00118: val_acc did not improve from 0.61313
# Epoch 119/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1696 - acc: 0.5546 - val_loss: 1.1315 - val_acc: 0.6020
#
# Epoch 00119: val_acc did not improve from 0.61313
# Epoch 120/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1789 - acc: 0.5458 - val_loss: 1.1379 - val_acc: 0.5950
#
# Epoch 00120: val_acc did not improve from 0.61313
# Epoch 121/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1791 - acc: 0.5543 - val_loss: 1.1376 - val_acc: 0.6061
#
# Epoch 00121: val_acc did not improve from 0.61313
# Epoch 122/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1805 - acc: 0.5528 - val_loss: 1.1377 - val_acc: 0.6047
#
# Epoch 00122: val_acc did not improve from 0.61313
# Epoch 123/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1832 - acc: 0.5554 - val_loss: 1.1278 - val_acc: 0.6103
#
# Epoch 00123: val_acc did not improve from 0.61313
# Epoch 124/300
# 6444/6444 [==============================] - 0s 54us/step - loss: 1.1705 - acc: 0.5580 - val_loss: 1.1308 - val_acc: 0.5978
#
# Epoch 00124: val_acc did not improve from 0.61313
# Epoch 125/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1745 - acc: 0.5448 - val_loss: 1.1223 - val_acc: 0.6131
#
# Epoch 00125: val_acc improved from 0.61313 to 0.61313, saving model to /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64
# Epoch 126/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1751 - acc: 0.5509 - val_loss: 1.1248 - val_acc: 0.6047
#
# Epoch 00126: val_acc did not improve from 0.61313
# Epoch 127/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1835 - acc: 0.5512 - val_loss: 1.1220 - val_acc: 0.6047
#
# Epoch 00127: val_acc did not improve from 0.61313
# Epoch 128/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1767 - acc: 0.5573 - val_loss: 1.1190 - val_acc: 0.6047
#
# Epoch 00128: val_acc did not improve from 0.61313
# Epoch 129/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1784 - acc: 0.5483 - val_loss: 1.1460 - val_acc: 0.5964
#
# Epoch 00129: val_acc did not improve from 0.61313
# Epoch 130/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1621 - acc: 0.5684 - val_loss: 1.1462 - val_acc: 0.6034
#
# Epoch 00130: val_acc did not improve from 0.61313
# Epoch 131/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1886 - acc: 0.5498 - val_loss: 1.1491 - val_acc: 0.6006
#
# Epoch 00131: val_acc did not improve from 0.61313
# Epoch 132/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1782 - acc: 0.5470 - val_loss: 1.1376 - val_acc: 0.5908
#
# Epoch 00132: val_acc did not improve from 0.61313
# Epoch 133/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1708 - acc: 0.5619 - val_loss: 1.1294 - val_acc: 0.5852
#
# Epoch 00133: val_acc did not improve from 0.61313
# Epoch 134/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1660 - acc: 0.5520 - val_loss: 1.1190 - val_acc: 0.5866
#
# Epoch 00134: val_acc did not improve from 0.61313
# Epoch 135/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1859 - acc: 0.5546 - val_loss: 1.1162 - val_acc: 0.6020
#
# Epoch 00135: val_acc did not improve from 0.61313
# Epoch 136/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1694 - acc: 0.5565 - val_loss: 1.1201 - val_acc: 0.5964
#
# Epoch 00136: val_acc did not improve from 0.61313
# Epoch 137/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1795 - acc: 0.5559 - val_loss: 1.1265 - val_acc: 0.5880
#
# Epoch 00137: val_acc did not improve from 0.61313
# Epoch 138/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1921 - acc: 0.5473 - val_loss: 1.1257 - val_acc: 0.5936
#
# Epoch 00138: val_acc did not improve from 0.61313
# Epoch 139/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1764 - acc: 0.5497 - val_loss: 1.1246 - val_acc: 0.5992
#
# Epoch 00139: val_acc did not improve from 0.61313
# Epoch 140/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1828 - acc: 0.5518 - val_loss: 1.1251 - val_acc: 0.6006
#
# Epoch 00140: val_acc did not improve from 0.61313
# Epoch 141/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1715 - acc: 0.5628 - val_loss: 1.1142 - val_acc: 0.6061
#
# Epoch 00141: val_acc did not improve from 0.61313
# Epoch 142/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1710 - acc: 0.5509 - val_loss: 1.1107 - val_acc: 0.5964
#
# Epoch 00142: val_acc did not improve from 0.61313
# Epoch 143/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1591 - acc: 0.5448 - val_loss: 1.1231 - val_acc: 0.5908
#
# Epoch 00143: val_acc did not improve from 0.61313
# Epoch 144/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1614 - acc: 0.5565 - val_loss: 1.1239 - val_acc: 0.6034
#
# Epoch 00144: val_acc did not improve from 0.61313
# Epoch 145/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1500 - acc: 0.5551 - val_loss: 1.1156 - val_acc: 0.6117
#
# Epoch 00145: val_acc did not improve from 0.61313
# Epoch 146/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1673 - acc: 0.5512 - val_loss: 1.1195 - val_acc: 0.5880
#
# Epoch 00146: val_acc did not improve from 0.61313
# Epoch 147/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1675 - acc: 0.5554 - val_loss: 1.1207 - val_acc: 0.5978
#
# Epoch 00147: val_acc did not improve from 0.61313
# Epoch 148/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1793 - acc: 0.5548 - val_loss: 1.1238 - val_acc: 0.6047
#
# Epoch 00148: val_acc did not improve from 0.61313
# Epoch 149/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1619 - acc: 0.5605 - val_loss: 1.1330 - val_acc: 0.5838
#
# Epoch 00149: val_acc did not improve from 0.61313
# Epoch 150/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1633 - acc: 0.5570 - val_loss: 1.1257 - val_acc: 0.6020
#
# Epoch 00150: val_acc did not improve from 0.61313
# Epoch 151/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1761 - acc: 0.5514 - val_loss: 1.1261 - val_acc: 0.6034
#
# Epoch 00151: val_acc did not improve from 0.61313
# Epoch 152/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1664 - acc: 0.5535 - val_loss: 1.1326 - val_acc: 0.6006
#
# Epoch 00152: val_acc did not improve from 0.61313
# Epoch 153/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1526 - acc: 0.5571 - val_loss: 1.1387 - val_acc: 0.5978
#
# Epoch 00153: val_acc did not improve from 0.61313
# Epoch 154/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1577 - acc: 0.5577 - val_loss: 1.1409 - val_acc: 0.6006
#
# Epoch 00154: val_acc did not improve from 0.61313
# Epoch 155/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1687 - acc: 0.5537 - val_loss: 1.1470 - val_acc: 0.6047
#
# Epoch 00155: val_acc did not improve from 0.61313
# Epoch 156/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1774 - acc: 0.5548 - val_loss: 1.1420 - val_acc: 0.6020
#
# Epoch 00156: val_acc did not improve from 0.61313
# Epoch 157/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1760 - acc: 0.5521 - val_loss: 1.1400 - val_acc: 0.5978
#
# Epoch 00157: val_acc did not improve from 0.61313
# Epoch 158/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1618 - acc: 0.5605 - val_loss: 1.1411 - val_acc: 0.5964
#
# Epoch 00158: val_acc did not improve from 0.61313
# Epoch 159/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1772 - acc: 0.5531 - val_loss: 1.1336 - val_acc: 0.5950
#
# Epoch 00159: val_acc did not improve from 0.61313
# Epoch 160/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1597 - acc: 0.5531 - val_loss: 1.1367 - val_acc: 0.5922
#
# Epoch 00160: val_acc did not improve from 0.61313
# Epoch 161/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1561 - acc: 0.5577 - val_loss: 1.1326 - val_acc: 0.5992
#
# Epoch 00161: val_acc did not improve from 0.61313
# Epoch 162/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1626 - acc: 0.5597 - val_loss: 1.1369 - val_acc: 0.5894
#
# Epoch 00162: val_acc did not improve from 0.61313
# Epoch 163/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1626 - acc: 0.5611 - val_loss: 1.1409 - val_acc: 0.5880
#
# Epoch 00163: val_acc did not improve from 0.61313
# Epoch 164/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1563 - acc: 0.5601 - val_loss: 1.1483 - val_acc: 0.5978
#
# Epoch 00164: val_acc did not improve from 0.61313
# Epoch 165/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1551 - acc: 0.5655 - val_loss: 1.1465 - val_acc: 0.5922
#
# Epoch 00165: val_acc did not improve from 0.61313
# Epoch 166/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1726 - acc: 0.5556 - val_loss: 1.1443 - val_acc: 0.5978
#
# Epoch 00166: val_acc did not improve from 0.61313
# Epoch 167/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1636 - acc: 0.5585 - val_loss: 1.1335 - val_acc: 0.5964
#
# Epoch 00167: val_acc did not improve from 0.61313
# Epoch 168/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1490 - acc: 0.5680 - val_loss: 1.1336 - val_acc: 0.6006
#
# Epoch 00168: val_acc did not improve from 0.61313
# Epoch 169/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1484 - acc: 0.5638 - val_loss: 1.1354 - val_acc: 0.6034
#
# Epoch 00169: val_acc did not improve from 0.61313
# Epoch 170/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1693 - acc: 0.5506 - val_loss: 1.1417 - val_acc: 0.6047
#
# Epoch 00170: val_acc did not improve from 0.61313
# Epoch 171/300
# 6444/6444 [==============================] - 0s 53us/step - loss: 1.1535 - acc: 0.5563 - val_loss: 1.1388 - val_acc: 0.6034
#
# Epoch 00171: val_acc did not improve from 0.61313
# Epoch 172/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1695 - acc: 0.5515 - val_loss: 1.1367 - val_acc: 0.6006
#
# Epoch 00172: val_acc did not improve from 0.61313
# Epoch 173/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1612 - acc: 0.5507 - val_loss: 1.1303 - val_acc: 0.6034
#
# Epoch 00173: val_acc did not improve from 0.61313
# Epoch 174/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1740 - acc: 0.5475 - val_loss: 1.1322 - val_acc: 0.6061
#
# Epoch 00174: val_acc did not improve from 0.61313
# Epoch 175/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1466 - acc: 0.5556 - val_loss: 1.1349 - val_acc: 0.5964
#
# Epoch 00175: val_acc did not improve from 0.61313
# Epoch 176/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1549 - acc: 0.5577 - val_loss: 1.1453 - val_acc: 0.6131
#
# Epoch 00176: val_acc did not improve from 0.61313
# Epoch 177/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1450 - acc: 0.5686 - val_loss: 1.1420 - val_acc: 0.5978
#
# Epoch 00177: val_acc did not improve from 0.61313
# Epoch 178/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1695 - acc: 0.5588 - val_loss: 1.1473 - val_acc: 0.5964
#
# Epoch 00178: val_acc did not improve from 0.61313
# Epoch 179/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1599 - acc: 0.5520 - val_loss: 1.1468 - val_acc: 0.5992
#
# Epoch 00179: val_acc did not improve from 0.61313
# Epoch 180/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1572 - acc: 0.5559 - val_loss: 1.1424 - val_acc: 0.6006
#
# Epoch 00180: val_acc did not improve from 0.61313
# Epoch 181/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1527 - acc: 0.5537 - val_loss: 1.1514 - val_acc: 0.5964
#
# Epoch 00181: val_acc did not improve from 0.61313
# Epoch 182/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1609 - acc: 0.5627 - val_loss: 1.1369 - val_acc: 0.6131
#
# Epoch 00182: val_acc did not improve from 0.61313
# Epoch 183/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1462 - acc: 0.5664 - val_loss: 1.1451 - val_acc: 0.6020
#
# Epoch 00183: val_acc did not improve from 0.61313
# Epoch 184/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1591 - acc: 0.5518 - val_loss: 1.1436 - val_acc: 0.5950
#
# Epoch 00184: val_acc did not improve from 0.61313
# Epoch 185/300
# 6444/6444 [==============================] - 0s 52us/step - loss: 1.1512 - acc: 0.5642 - val_loss: 1.1421 - val_acc: 0.5978
#
# Epoch 00185: val_acc did not improve from 0.61313
# Epoch 00185: early stopping

# %%
plt.plot(train_loss, 'b', label='train')
plt.plot(valid_loss, 'r', label='valid')
plt.legend()
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()
plt.savefig

plt.plot(train_acc, 'b', label='train')
plt.plot(valid_acc, 'r', label='valid')
plt.title("Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# train_loss = model_history.history['loss']
# train_acc = model_history.history['acc']
# valid_loss = model_history.history['val_loss']
# valid_acc = model_history.history['val_acc']

# %% [markdown]
# plt.plot(train_loss, 'b', label='train')
# plt.plot(valid_loss, 'r', label='valid')
# plt.legend()
# plt.title("Loss")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.legend(loc='best')
# plt.show()
#
# plt.plot(train_acc, 'b', label='train')
# plt.plot(valid_acc, 'r', label='valid')
# plt.title("Accuracy")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.legend(loc='best')
# plt.show()

# %%
# save model，存最後的結果。
# 此case是用checkpoint存最佳的valid accuracy結果，所以將此mark掉
#model.save('my_model.h5')

# %% [markdown]
# ## 取訓練時最佳的結果來做test預測

# %%
# load model
print (best_model_path_name)
best_model = load_model(best_model_path_name)
# Out:
# /home/jovyan/mypython/Kaggle/AIA Pokemon/saved_models/adam_64

# %%
y_test_pred = best_model.predict_classes(x_test)

# %%
## 將預測結果與ID做combine
prediction = pd.DataFrame(y_test_pred, columns=['class'])
result = pd.concat([x_test_id, prediction], axis=1)
result.head()
# Out:
#                              id  class
# 0  MTA5MTEwOTYxMzM0NzA2NDEzNzM=      2
# 1  MTY0OTUyMTM2MDExMjg3MjczMjU=      1
# 2  MTQ0ODU1OTEzOTU1NTAyNzI4NjE=      4
# 3  MTY1ODg1MzEwNzYzNDUzMDUwNTM=      3
# 4  MTY0NTg2OTA5MTkzOTE2MTc1MTc=      5

# %%
#儲存結果
result.to_csv('submission_dl.csv', index=False)
