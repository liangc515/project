# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns       
from scipy import stats

import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline  
# 为了在jupyter notebook里作图，需要用到这个命令

# %% [markdown]
# ## Load train data and test data
# #### 並先刪除不必要的欄位

# %%
train = pd.read_csv("train.csv")
#train.drop("ID", axis = 1, inplace = True)
print (train.shape)
# 取出train data的y值
y_train=train['class']
print ("y_train:",y_train.shape)
train.drop(["ID","class"], axis = 1, inplace = True)
x_train=train
print ("x_train:",x_train.shape)
# Out:
# (7160, 184)
# y_train: (7160,)
# x_train: (7160, 182)

# %%
x_test = pd.read_csv("test.csv")
x_test_id=x_test["id"]
x_test.drop(["id"], axis = 1, inplace = True)
print ("x_test:",x_test.shape)
print (train.info())
# Out:
# x_test: (1791, 182)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7160 entries, 0 to 7159
# Columns: 182 entries, appearedTimeOfDay to cooc_151
# dtypes: bool(168), float64(6), int64(3), object(5)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ## 將train data和test data combine起來，後續一起做資料處理
# #### 如果分開做的話，做one-hot-encoding時可能會有feature數量不一致的問題

# %%
data=pd.concat([x_train,x_test],axis=0,ignore_index = False)
print (data.shape)
#紀錄train data的筆數,後續EDA完成後要再依此筆數拆分train data和test data
x_train_qty=x_train.shape[0]
# Out:
# (8951, 182)

# %% [markdown]
# ## 判斷fetures是屬於categorical or numerical

# %%
# Differentiate numerical features (minus the target) and categorical features
categorical_features = data.select_dtypes(include=['object']).columns
print(categorical_features)
numerical_features = data.select_dtypes(exclude = ["object"]).columns
print(numerical_features)
print("Categorical features : " + str(len(categorical_features)))
print("Numerical features : " + str(len(numerical_features)))
# Out:
# Index(['appearedTimeOfDay', 'city', 'continent', 'weather', 'weatherIcon'], dtype='object')
# Index(['appearedHour', 'appearedMinute', 'terrainType', 'closeToWater',
#        'temperature', 'windSpeed', 'pressure', 'population_density', 'urban',
#        'suburban',
#        ...
#        'cooc_142', 'cooc_143', 'cooc_144', 'cooc_145', 'cooc_146', 'cooc_147',
#        'cooc_148', 'cooc_149', 'cooc_150', 'cooc_151'],
#       dtype='object', length=177)
# Categorical features : 5
# Numerical features : 177

# %% [markdown]
# ## 檢查Features datatype

# %%
print(data.dtypes.unique())
print(len(data.select_dtypes(include=['O']).columns))
print(data.select_dtypes(include=['O']).columns)
# Out:
# [dtype('O') dtype('int64') dtype('bool') dtype('float64')]
# 5
# Index(['appearedTimeOfDay', 'city', 'continent', 'weather', 'weatherIcon'], dtype='object')

# %%
data.head()
# Out:
#   appearedTimeOfDay  appearedHour  appearedMinute  terrainType  closeToWater  \
# 0           evening            19              10           13         False
# 1             night             5              19           13          True
# 2           evening            19              46            0          True
# 3           morning            11              10            0          True
# 4           evening            18              32           13          True
#
#           city  continent       weather  temperature  windSpeed    ...     \
# 0      Bangkok       Asia         Clear         27.8       9.00    ...
# 1     New_York    America         Clear         26.1       8.70    ...
# 2     New_York    America         Clear         24.7      16.82    ...
# 3       Hobart  Australia         Clear         12.7      13.25    ...
# 4  Los_Angeles    America  PartlyCloudy         19.1       5.78    ...
#
#    cooc_142 cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0     False    False     False     False     False     False     False
# 1     False    False     False     False     False     False     False
# 2     False    False     False     False     False     False     False
# 3     False    False     False     False     False     False     False
# 4     False    False     False     False     False     False     False
#
#    cooc_149  cooc_150  cooc_151
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 182 columns]

# %%
data.describe()
# Out:
#        appearedHour  appearedMinute  terrainType  temperature    windSpeed  \
# count   8951.000000     8951.000000  8951.000000  8951.000000  8951.000000
# mean      10.654452       30.643168     9.720590    23.281008     7.510169
# std        7.152858       17.439499     4.941831     6.054764     4.617323
# min        0.000000        0.000000     0.000000     4.800000     0.000000
# 25%        4.000000       16.000000     7.000000    18.500000     3.920000
# 50%       10.000000       32.000000    13.000000    23.800000     6.630000
# 75%       17.000000       46.000000    13.000000    27.500000    10.010000
# max       23.000000       59.000000    16.000000    41.200000    56.130000
#
#           pressure  population_density  gymDistanceKm  pokestopDistanceKm
# count  8951.000000         8951.000000    8951.000000         8951.000000
# mean   1014.904328         1541.905140       2.987937            0.562947
# std       5.828866         2230.860698      46.908371            7.479374
# min     996.330000            0.000000       0.004516            0.000319
# 25%    1010.695000           69.585650       0.178437            0.050817
# 50%    1015.290000          635.549800       0.314365            0.132209
# 75%    1019.290000         1955.863600       0.577406            0.310317
# max    1034.170000        10000.000000    3859.424664          455.313099

# %% [markdown]
# ## 處理時間欄位

# %%
data['appearedtime'] = data['appearedHour']+(data['appearedMinute']/60)
#maxtime=data['appearedtime'].max()
maxtime=24
data['appearedtime'].head()
# Out:
# 0    19.166667
# 1     5.316667
# 2    19.766667
# 3    11.166667
# 4    18.533333
# Name: appearedtime, dtype: float64

# %%
data['appearedtime_sin'] = np.sin(2 * np.pi * data['appearedtime']/maxtime)
data['appearedtime_cos'] = np.cos(2 * np.pi * data['appearedtime']/maxtime)

# %%
ax = data.plot.scatter('appearedtime_sin', 'appearedtime_cos').set_aspect('equal')

# %% [markdown]
# ## 刪除不需要的features

# %%
# city已經可以區分地區,所以不需要continent
data = data.drop(['continent'], axis=1)
#與weather類似，所以移除weatherIcon
data = data.drop(['weatherIcon'], axis=1)
#data = data.drop(['weather'], axis=1)
data = data.drop(['appearedHour', 'appearedMinute','appearedtime'], axis=1)
# 時間欄位與appearedTimeOfDay效果相似,保留appearedTimeOfDay
#data = data.drop(['appearedTimeOfDay'], axis=1)
data = data.drop(['appearedtime_sin', 'appearedtime_cos'], axis=1)

# %% [markdown]
# ## 顯示數值欄位基本資訊

# %%
data.describe()
# Out:
#        terrainType  temperature    windSpeed     pressure  population_density  \
# count  8951.000000  8951.000000  8951.000000  8951.000000         8951.000000
# mean      9.720590    23.281008     7.510169  1014.904328         1541.905140
# std       4.941831     6.054764     4.617323     5.828866         2230.860698
# min       0.000000     4.800000     0.000000   996.330000            0.000000
# 25%       7.000000    18.500000     3.920000  1010.695000           69.585650
# 50%      13.000000    23.800000     6.630000  1015.290000          635.549800
# 75%      13.000000    27.500000    10.010000  1019.290000         1955.863600
# max      16.000000    41.200000    56.130000  1034.170000        10000.000000
#
#        gymDistanceKm  pokestopDistanceKm
# count    8951.000000         8951.000000
# mean        2.987937            0.562947
# std        46.908371            7.479374
# min         0.004516            0.000319
# 25%         0.178437            0.050817
# 50%         0.314365            0.132209
# 75%         0.577406            0.310317
# max      3859.424664          455.313099

# %% [markdown]
# ## 判斷是否有missing data

# %%
# Missing data in train
data_na = data.isnull().sum()
data_na = data_na[data_na>0]
data_na.sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 查看min為0的筆數是否異常

# %%
print (data.loc[(data['population_density']==0),'population_density'].count())
data.loc[(data['population_density']==0),'population_density'].count()/data.shape[0]
# Out:
# 1652
# 0.18456038431460173

# %% [markdown]
# ## 將數值為不應該為0的值改用平均值

# %%
# 使用該city的population_density平均值取代0值
for i in data['city'].unique():
    mean=data[data['city']==i].loc[:,'population_density'].mean()
    data.loc[(data['city']==i) & (data['population_density']==0),'population_density']=mean

# %%
data.head()
# Out:
#   appearedTimeOfDay  terrainType  closeToWater         city       weather  \
# 0           evening           13         False      Bangkok         Clear
# 1             night           13          True     New_York         Clear
# 2           evening            0          True     New_York         Clear
# 3           morning            0          True       Hobart         Clear
# 4           evening           13          True  Los_Angeles  PartlyCloudy
#
#    temperature  windSpeed  pressure  population_density  urban    ...     \
# 0         27.8       9.00   1008.96          6019.04440   True    ...
# 1         26.1       8.70   1018.96          1172.14576  False    ...
# 2         24.7      16.82   1023.22          1172.14576  False    ...
# 3         12.7      13.25   1014.19           128.89505  False    ...
# 4         19.1       5.78   1011.36          4188.39100   True    ...
#
#    cooc_142  cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0     False     False     False     False     False     False     False
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
#
#    cooc_149  cooc_150  cooc_151
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 178 columns]

# %%
data.describe()
# Out:
#        terrainType  temperature    windSpeed     pressure  population_density  \
# count  8951.000000  8951.000000  8951.000000  8951.000000         8951.000000
# mean      9.720590    23.281008     7.510169  1014.904328         1786.441753
# std       4.941831     6.054764     4.617323     5.828866         2143.401196
# min       0.000000     4.800000     0.000000   996.330000            0.000000
# 25%       7.000000    18.500000     3.920000  1010.695000          458.582340
# 50%      13.000000    23.800000     6.630000  1015.290000         1135.319600
# 75%      13.000000    27.500000    10.010000  1019.290000         2261.157000
# max      16.000000    41.200000    56.130000  1034.170000        10000.000000
#
#        gymDistanceKm  pokestopDistanceKm
# count    8951.000000         8951.000000
# mean        2.987937            0.562947
# std        46.908371            7.479374
# min         0.004516            0.000319
# 25%         0.178437            0.050817
# 50%         0.314365            0.132209
# 75%         0.577406            0.310317
# max      3859.424664          455.313099

# %% [markdown]
# ## 將以數值做分類型態的feature的資料型態轉換成字串，避免訓練時被當作數值處理
# #### 例terrainType是以0,1,2..來表示不同種類的地形，但並非數值，所以要做轉換

# %%
#data.terrainType = data.terrainType.astype( str )
features_to_str=["terrainType"]
data[features_to_str]=data[features_to_str].astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8951 entries, 0 to 1790
# Columns: 178 entries, appearedTimeOfDay to cooc_151
# dtypes: bool(168), float64(6), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# ## 對數值欄位做 normalization

# %%
from sklearn import preprocessing
# 前面已經取過一次numerical_features,但因為中間features有增減，所以再取一次
numerical_features = data.select_dtypes(exclude = ["object"]).columns
data[numerical_features] = preprocessing.scale(data[numerical_features])
print (data.head())
# Out:
#   appearedTimeOfDay terrainType  closeToWater         city       weather  \
# 0           evening          13     -0.901079      Bangkok         Clear
# 1             night          13      1.109781     New_York         Clear
# 2           evening           0      1.109781     New_York         Clear
# 3           morning           0      1.109781       Hobart         Clear
# 4           evening          13      1.109781  Los_Angeles  PartlyCloudy
#
#    temperature  windSpeed  pressure  population_density     urban    ...     \
# 0     0.746395   0.322679 -1.019866            1.974824  1.133395    ...
# 1     0.465609   0.257703  0.695830           -0.286615 -0.882305    ...
# 2     0.234373   2.016396  1.426716           -0.286615 -0.882305    ...
# 3    -1.747648   1.243178 -0.122557           -0.773369 -0.882305    ...
# 4    -0.690571  -0.374733 -0.608099            1.120688  1.133395    ...
#
#    cooc_142  cooc_143  cooc_144  cooc_145  cooc_146  cooc_147  cooc_148  \
# 0  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 1  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 2  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 3  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
# 4  -0.01057 -0.021144       0.0       0.0       0.0  -0.10302 -0.033443
#
#    cooc_149  cooc_150  cooc_151
# 0 -0.021144       0.0       0.0
# 1 -0.021144       0.0       0.0
# 2 -0.021144       0.0       0.0
# 3 -0.021144       0.0       0.0
# 4 -0.021144       0.0       0.0
#
# [5 rows x 178 columns]

# %% [markdown]
# ## 對類別型欄位做one-hot-encoding
# #### 某一類別型feature有三個值，則會被轉換成三個features

# %%
data=pd.get_dummies(data)
data.shape
# Out:
# (8951, 292)

# %%
feture_qty=data.shape[1]
print (feture_qty)
# Out:
# 292

# %% [markdown]
# ## 將整理後的資料再拆成train data和test data

# %%
x_train=data[:x_train_qty]
x_test=data[x_train_qty:]
print (x_train.shape)
print (x_test.shape)
# Out:
# (7160, 292)
# (1791, 292)

# %% [markdown]
# ## one hot encoding - train data y

# %%
# one hot encoding
y_one_hot = np.zeros((len(y_train), 6))  
y_one_hot[np.arange(len(y_train)), y_train] = 1

print (y_one_hot.shape)
# Out:
# (7160, 6)

# %% [markdown]
# ## 用 keras 建 model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#使用dropout無太大變化
#使用2個隱藏層沒太大變化
model = tf.keras.Sequential()
model.add(Dropout(0.4, input_shape=(feture_qty,)))
model.add(Dense(200,activation='relu'))
#model.add(Dense(128, activation='relu', input_shape=(feture_qty,)))
model.add(Dropout(0.4))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
#model.add(Dense(50, activation='relu')) #多這一層沒幫助
#model.add(Dropout(0.3))
model.add(Dense(6, activation='softmax')) 

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_96 (Dropout)         (None, 292)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 200)               58600
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 6)                 606
# =================================================================
# Total params: 79,306
# Trainable params: 79,306
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
batch_size = 200 #原本32放大有幫助
epochs = 200 #batch_size調大,epochs也要調大
lr = 0.001 #原本0.01調小有幫助
train_ratio = 0.85 # 調整稍有變化

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %% [markdown]
# ## 取最佳訓練結果-使用ModelCheckpoint方式

# %%
filepath="weights-best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', 
                             verbose=2, save_best_only=True, save_weights_only=False)

# %%
model_history = model.fit(x=x_train, y=y_one_hot,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_split=1 - train_ratio, callbacks=[checkpoint])

#model_history = model.fit(x=x_train, y=y_one_hot,
#                          batch_size=batch_size,
#                          epochs=epochs,
#                          validation_split=1 - train_ratio)
# Out:
# Train on 6086 samples, validate on 1074 samples
# Epoch 1/200
# 6086/6086 [==============================] - 3s 480us/step - loss: 1.9018 - acc: 0.2456 - val_loss: 1.5999 - val_acc: 0.4218
#
# Epoch 00001: val_acc improved from -inf to 0.42179, saving model to weights-best.hdf5
# Epoch 2/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.6854 - acc: 0.3382 - val_loss: 1.4988 - val_acc: 0.4683
#
# Epoch 00002: val_acc improved from 0.42179 to 0.46834, saving model to weights-best.hdf5
# Epoch 3/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.5898 - acc: 0.3781 - val_loss: 1.4171 - val_acc: 0.4879
#
# Epoch 00003: val_acc improved from 0.46834 to 0.48790, saving model to weights-best.hdf5
# Epoch 4/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.5157 - acc: 0.4144 - val_loss: 1.3605 - val_acc: 0.5196
#
# Epoch 00004: val_acc improved from 0.48790 to 0.51955, saving model to weights-best.hdf5
# Epoch 5/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.4864 - acc: 0.4211 - val_loss: 1.3297 - val_acc: 0.5102
#
# Epoch 00005: val_acc did not improve from 0.51955
# Epoch 6/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.4493 - acc: 0.4354 - val_loss: 1.2989 - val_acc: 0.5251
#
# Epoch 00006: val_acc improved from 0.51955 to 0.52514, saving model to weights-best.hdf5
# Epoch 7/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.4282 - acc: 0.4423 - val_loss: 1.2772 - val_acc: 0.5233
#
# Epoch 00007: val_acc did not improve from 0.52514
# Epoch 8/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.4081 - acc: 0.4548 - val_loss: 1.2639 - val_acc: 0.5317
#
# Epoch 00008: val_acc improved from 0.52514 to 0.53166, saving model to weights-best.hdf5
# Epoch 9/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3868 - acc: 0.4570 - val_loss: 1.2530 - val_acc: 0.5354
#
# Epoch 00009: val_acc improved from 0.53166 to 0.53538, saving model to weights-best.hdf5
# Epoch 10/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3845 - acc: 0.4616 - val_loss: 1.2429 - val_acc: 0.5382
#
# Epoch 00010: val_acc improved from 0.53538 to 0.53818, saving model to weights-best.hdf5
# Epoch 11/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3533 - acc: 0.4596 - val_loss: 1.2331 - val_acc: 0.5428
#
# Epoch 00011: val_acc improved from 0.53818 to 0.54283, saving model to weights-best.hdf5
# Epoch 12/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3607 - acc: 0.4716 - val_loss: 1.2274 - val_acc: 0.5438
#
# Epoch 00012: val_acc improved from 0.54283 to 0.54376, saving model to weights-best.hdf5
# Epoch 13/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3644 - acc: 0.4635 - val_loss: 1.2269 - val_acc: 0.5382
#
# Epoch 00013: val_acc did not improve from 0.54376
# Epoch 14/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.3322 - acc: 0.4804 - val_loss: 1.2167 - val_acc: 0.5475
#
# Epoch 00014: val_acc improved from 0.54376 to 0.54749, saving model to weights-best.hdf5
# Epoch 15/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.3397 - acc: 0.4819 - val_loss: 1.2121 - val_acc: 0.5549
#
# Epoch 00015: val_acc improved from 0.54749 to 0.55493, saving model to weights-best.hdf5
# Epoch 16/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3217 - acc: 0.4908 - val_loss: 1.2069 - val_acc: 0.5521
#
# Epoch 00016: val_acc did not improve from 0.55493
# Epoch 17/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3344 - acc: 0.4837 - val_loss: 1.2016 - val_acc: 0.5596
#
# Epoch 00017: val_acc improved from 0.55493 to 0.55959, saving model to weights-best.hdf5
# Epoch 18/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3217 - acc: 0.4905 - val_loss: 1.2048 - val_acc: 0.5540
#
# Epoch 00018: val_acc did not improve from 0.55959
# Epoch 19/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3035 - acc: 0.4926 - val_loss: 1.1954 - val_acc: 0.5503
#
# Epoch 00019: val_acc did not improve from 0.55959
# Epoch 20/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3048 - acc: 0.4883 - val_loss: 1.1986 - val_acc: 0.5577
#
# Epoch 00020: val_acc did not improve from 0.55959
# Epoch 21/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3003 - acc: 0.5010 - val_loss: 1.1942 - val_acc: 0.5577
#
# Epoch 00021: val_acc did not improve from 0.55959
# Epoch 22/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2924 - acc: 0.4928 - val_loss: 1.1989 - val_acc: 0.5661
#
# Epoch 00022: val_acc improved from 0.55959 to 0.56611, saving model to weights-best.hdf5
# Epoch 23/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.3010 - acc: 0.4965 - val_loss: 1.1911 - val_acc: 0.5642
#
# Epoch 00023: val_acc did not improve from 0.56611
# Epoch 24/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2918 - acc: 0.5046 - val_loss: 1.1905 - val_acc: 0.5652
#
# Epoch 00024: val_acc did not improve from 0.56611
# Epoch 25/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2888 - acc: 0.4911 - val_loss: 1.1857 - val_acc: 0.5624
#
# Epoch 00025: val_acc did not improve from 0.56611
# Epoch 26/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2830 - acc: 0.4992 - val_loss: 1.1823 - val_acc: 0.5708
#
# Epoch 00026: val_acc improved from 0.56611 to 0.57076, saving model to weights-best.hdf5
# Epoch 27/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2717 - acc: 0.5081 - val_loss: 1.1736 - val_acc: 0.5708
#
# Epoch 00027: val_acc improved from 0.57076 to 0.57076, saving model to weights-best.hdf5
# Epoch 28/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2725 - acc: 0.5044 - val_loss: 1.1762 - val_acc: 0.5764
#
# Epoch 00028: val_acc improved from 0.57076 to 0.57635, saving model to weights-best.hdf5
# Epoch 29/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2634 - acc: 0.5031 - val_loss: 1.1780 - val_acc: 0.5717
#
# Epoch 00029: val_acc did not improve from 0.57635
# Epoch 30/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2677 - acc: 0.5058 - val_loss: 1.1770 - val_acc: 0.5726
#
# Epoch 00030: val_acc did not improve from 0.57635
# Epoch 31/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2737 - acc: 0.5095 - val_loss: 1.1787 - val_acc: 0.5791
#
# Epoch 00031: val_acc improved from 0.57635 to 0.57914, saving model to weights-best.hdf5
# Epoch 32/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2561 - acc: 0.5169 - val_loss: 1.1738 - val_acc: 0.5838
#
# Epoch 00032: val_acc improved from 0.57914 to 0.58380, saving model to weights-best.hdf5
# Epoch 33/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2606 - acc: 0.5130 - val_loss: 1.1719 - val_acc: 0.5698
#
# Epoch 00033: val_acc did not improve from 0.58380
# Epoch 34/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2459 - acc: 0.5141 - val_loss: 1.1696 - val_acc: 0.5791
#
# Epoch 00034: val_acc did not improve from 0.58380
# Epoch 35/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2503 - acc: 0.5168 - val_loss: 1.1686 - val_acc: 0.5801
#
# Epoch 00035: val_acc did not improve from 0.58380
# Epoch 36/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2572 - acc: 0.5148 - val_loss: 1.1677 - val_acc: 0.5829
#
# Epoch 00036: val_acc did not improve from 0.58380
# Epoch 37/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2467 - acc: 0.5182 - val_loss: 1.1679 - val_acc: 0.5773
#
# Epoch 00037: val_acc did not improve from 0.58380
# Epoch 38/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2434 - acc: 0.5138 - val_loss: 1.1649 - val_acc: 0.5903
#
# Epoch 00038: val_acc improved from 0.58380 to 0.59032, saving model to weights-best.hdf5
# Epoch 39/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2324 - acc: 0.5306 - val_loss: 1.1659 - val_acc: 0.5894
#
# Epoch 00039: val_acc did not improve from 0.59032
# Epoch 40/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2360 - acc: 0.5133 - val_loss: 1.1668 - val_acc: 0.5847
#
# Epoch 00040: val_acc did not improve from 0.59032
# Epoch 41/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2488 - acc: 0.5176 - val_loss: 1.1730 - val_acc: 0.5791
#
# Epoch 00041: val_acc did not improve from 0.59032
# Epoch 42/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2328 - acc: 0.5199 - val_loss: 1.1683 - val_acc: 0.5857
#
# Epoch 00042: val_acc did not improve from 0.59032
# Epoch 43/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2417 - acc: 0.5207 - val_loss: 1.1681 - val_acc: 0.5885
#
# Epoch 00043: val_acc did not improve from 0.59032
# Epoch 44/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2331 - acc: 0.5271 - val_loss: 1.1683 - val_acc: 0.5847
#
# Epoch 00044: val_acc did not improve from 0.59032
# Epoch 45/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2218 - acc: 0.5250 - val_loss: 1.1643 - val_acc: 0.5838
#
# Epoch 00045: val_acc did not improve from 0.59032
# Epoch 46/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2418 - acc: 0.5171 - val_loss: 1.1655 - val_acc: 0.5764
#
# Epoch 00046: val_acc did not improve from 0.59032
# Epoch 47/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2233 - acc: 0.5227 - val_loss: 1.1640 - val_acc: 0.5810
#
# Epoch 00047: val_acc did not improve from 0.59032
# Epoch 48/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.2366 - acc: 0.5154 - val_loss: 1.1632 - val_acc: 0.5801
#
# Epoch 00048: val_acc did not improve from 0.59032
# Epoch 49/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2270 - acc: 0.5271 - val_loss: 1.1665 - val_acc: 0.5810
#
# Epoch 00049: val_acc did not improve from 0.59032
# Epoch 50/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2247 - acc: 0.5266 - val_loss: 1.1597 - val_acc: 0.5931
#
# Epoch 00050: val_acc improved from 0.59032 to 0.59311, saving model to weights-best.hdf5
# Epoch 51/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2185 - acc: 0.5191 - val_loss: 1.1598 - val_acc: 0.5866
#
# Epoch 00051: val_acc did not improve from 0.59311
# Epoch 52/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2123 - acc: 0.5302 - val_loss: 1.1601 - val_acc: 0.5857
#
# Epoch 00052: val_acc did not improve from 0.59311
# Epoch 53/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2073 - acc: 0.5381 - val_loss: 1.1566 - val_acc: 0.5950
#
# Epoch 00053: val_acc improved from 0.59311 to 0.59497, saving model to weights-best.hdf5
# Epoch 54/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2206 - acc: 0.5251 - val_loss: 1.1590 - val_acc: 0.5866
#
# Epoch 00054: val_acc did not improve from 0.59497
# Epoch 55/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2026 - acc: 0.5320 - val_loss: 1.1599 - val_acc: 0.5838
#
# Epoch 00055: val_acc did not improve from 0.59497
# Epoch 56/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2084 - acc: 0.5292 - val_loss: 1.1612 - val_acc: 0.5810
#
# Epoch 00056: val_acc did not improve from 0.59497
# Epoch 57/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2052 - acc: 0.5296 - val_loss: 1.1571 - val_acc: 0.5838
#
# Epoch 00057: val_acc did not improve from 0.59497
# Epoch 58/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2112 - acc: 0.5240 - val_loss: 1.1617 - val_acc: 0.5857
#
# Epoch 00058: val_acc did not improve from 0.59497
# Epoch 59/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2094 - acc: 0.5320 - val_loss: 1.1619 - val_acc: 0.5838
#
# Epoch 00059: val_acc did not improve from 0.59497
# Epoch 60/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1997 - acc: 0.5330 - val_loss: 1.1576 - val_acc: 0.5875
#
# Epoch 00060: val_acc did not improve from 0.59497
# Epoch 61/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1996 - acc: 0.5355 - val_loss: 1.1611 - val_acc: 0.5773
#
# Epoch 00061: val_acc did not improve from 0.59497
# Epoch 62/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1934 - acc: 0.5337 - val_loss: 1.1601 - val_acc: 0.5810
#
# Epoch 00062: val_acc did not improve from 0.59497
# Epoch 63/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2074 - acc: 0.5276 - val_loss: 1.1569 - val_acc: 0.5838
#
# Epoch 00063: val_acc did not improve from 0.59497
# Epoch 64/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2051 - acc: 0.5327 - val_loss: 1.1593 - val_acc: 0.5959
#
# Epoch 00064: val_acc improved from 0.59497 to 0.59590, saving model to weights-best.hdf5
# Epoch 65/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2021 - acc: 0.5427 - val_loss: 1.1606 - val_acc: 0.5903
#
# Epoch 00065: val_acc did not improve from 0.59590
# Epoch 66/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1889 - acc: 0.5360 - val_loss: 1.1583 - val_acc: 0.5950
#
# Epoch 00066: val_acc did not improve from 0.59590
# Epoch 67/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1872 - acc: 0.5414 - val_loss: 1.1570 - val_acc: 0.5894
#
# Epoch 00067: val_acc did not improve from 0.59590
# Epoch 68/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1922 - acc: 0.5401 - val_loss: 1.1554 - val_acc: 0.5996
#
# Epoch 00068: val_acc improved from 0.59590 to 0.59963, saving model to weights-best.hdf5
# Epoch 69/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.2024 - acc: 0.5325 - val_loss: 1.1526 - val_acc: 0.5968
#
# Epoch 00069: val_acc did not improve from 0.59963
# Epoch 70/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1932 - acc: 0.5403 - val_loss: 1.1497 - val_acc: 0.5978
#
# Epoch 00070: val_acc did not improve from 0.59963
# Epoch 71/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1987 - acc: 0.5399 - val_loss: 1.1507 - val_acc: 0.6061
#
# Epoch 00071: val_acc improved from 0.59963 to 0.60615, saving model to weights-best.hdf5
# Epoch 72/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1865 - acc: 0.5468 - val_loss: 1.1557 - val_acc: 0.5978
#
# Epoch 00072: val_acc did not improve from 0.60615
# Epoch 73/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1848 - acc: 0.5463 - val_loss: 1.1538 - val_acc: 0.6006
#
# Epoch 00073: val_acc did not improve from 0.60615
# Epoch 74/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1908 - acc: 0.5391 - val_loss: 1.1529 - val_acc: 0.5996
#
# Epoch 00074: val_acc did not improve from 0.60615
# Epoch 75/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1842 - acc: 0.5442 - val_loss: 1.1512 - val_acc: 0.5987
#
# Epoch 00075: val_acc did not improve from 0.60615
# Epoch 76/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1792 - acc: 0.5483 - val_loss: 1.1528 - val_acc: 0.5885
#
# Epoch 00076: val_acc did not improve from 0.60615
# Epoch 77/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1757 - acc: 0.5472 - val_loss: 1.1525 - val_acc: 0.5950
#
# Epoch 00077: val_acc did not improve from 0.60615
# Epoch 78/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1791 - acc: 0.5442 - val_loss: 1.1529 - val_acc: 0.5894
#
# Epoch 00078: val_acc did not improve from 0.60615
# Epoch 79/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1889 - acc: 0.5414 - val_loss: 1.1503 - val_acc: 0.5885
#
# Epoch 00079: val_acc did not improve from 0.60615
# Epoch 80/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1890 - acc: 0.5380 - val_loss: 1.1480 - val_acc: 0.5903
#
# Epoch 00080: val_acc did not improve from 0.60615
# Epoch 81/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1689 - acc: 0.5414 - val_loss: 1.1504 - val_acc: 0.5922
#
# Epoch 00081: val_acc did not improve from 0.60615
# Epoch 82/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1714 - acc: 0.5388 - val_loss: 1.1513 - val_acc: 0.5959
#
# Epoch 00082: val_acc did not improve from 0.60615
# Epoch 83/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1895 - acc: 0.5391 - val_loss: 1.1489 - val_acc: 0.5996
#
# Epoch 00083: val_acc did not improve from 0.60615
# Epoch 84/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1717 - acc: 0.5547 - val_loss: 1.1499 - val_acc: 0.5885
#
# Epoch 00084: val_acc did not improve from 0.60615
# Epoch 85/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1700 - acc: 0.5370 - val_loss: 1.1483 - val_acc: 0.5912
#
# Epoch 00085: val_acc did not improve from 0.60615
# Epoch 86/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1799 - acc: 0.5421 - val_loss: 1.1521 - val_acc: 0.5922
#
# Epoch 00086: val_acc did not improve from 0.60615
# Epoch 87/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1579 - acc: 0.5531 - val_loss: 1.1486 - val_acc: 0.5950
#
# Epoch 00087: val_acc did not improve from 0.60615
# Epoch 88/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1697 - acc: 0.5503 - val_loss: 1.1514 - val_acc: 0.5931
#
# Epoch 00088: val_acc did not improve from 0.60615
# Epoch 89/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1629 - acc: 0.5483 - val_loss: 1.1556 - val_acc: 0.5912
#
# Epoch 00089: val_acc did not improve from 0.60615
# Epoch 90/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1787 - acc: 0.5503 - val_loss: 1.1586 - val_acc: 0.5950
#
# Epoch 00090: val_acc did not improve from 0.60615
# Epoch 91/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1749 - acc: 0.5503 - val_loss: 1.1554 - val_acc: 0.5903
#
# Epoch 00091: val_acc did not improve from 0.60615
# Epoch 92/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1622 - acc: 0.5481 - val_loss: 1.1543 - val_acc: 0.5959
#
# Epoch 00092: val_acc did not improve from 0.60615
# Epoch 93/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1679 - acc: 0.5542 - val_loss: 1.1511 - val_acc: 0.5894
#
# Epoch 00093: val_acc did not improve from 0.60615
# Epoch 94/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1635 - acc: 0.5480 - val_loss: 1.1525 - val_acc: 0.5819
#
# Epoch 00094: val_acc did not improve from 0.60615
# Epoch 95/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1681 - acc: 0.5511 - val_loss: 1.1515 - val_acc: 0.5903
#
# Epoch 00095: val_acc did not improve from 0.60615
# Epoch 96/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1397 - acc: 0.5547 - val_loss: 1.1401 - val_acc: 0.6024
#
# Epoch 00096: val_acc did not improve from 0.60615
# Epoch 97/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1590 - acc: 0.5523 - val_loss: 1.1451 - val_acc: 0.5922
#
# Epoch 00097: val_acc did not improve from 0.60615
# Epoch 98/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1700 - acc: 0.5519 - val_loss: 1.1459 - val_acc: 0.5959
#
# Epoch 00098: val_acc did not improve from 0.60615
# Epoch 99/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1572 - acc: 0.5569 - val_loss: 1.1430 - val_acc: 0.6006
#
# Epoch 00099: val_acc did not improve from 0.60615
# Epoch 100/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1536 - acc: 0.5542 - val_loss: 1.1444 - val_acc: 0.6006
#
# Epoch 00100: val_acc did not improve from 0.60615
# Epoch 101/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1607 - acc: 0.5486 - val_loss: 1.1486 - val_acc: 0.5950
#
# Epoch 00101: val_acc did not improve from 0.60615
# Epoch 102/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1745 - acc: 0.5463 - val_loss: 1.1498 - val_acc: 0.6043
#
# Epoch 00102: val_acc did not improve from 0.60615
# Epoch 103/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1622 - acc: 0.5518 - val_loss: 1.1449 - val_acc: 0.6006
#
# Epoch 00103: val_acc did not improve from 0.60615
# Epoch 104/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1550 - acc: 0.5544 - val_loss: 1.1463 - val_acc: 0.6034
#
# Epoch 00104: val_acc did not improve from 0.60615
# Epoch 105/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1583 - acc: 0.5541 - val_loss: 1.1471 - val_acc: 0.5978
#
# Epoch 00105: val_acc did not improve from 0.60615
# Epoch 106/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1525 - acc: 0.5546 - val_loss: 1.1456 - val_acc: 0.5996
#
# Epoch 00106: val_acc did not improve from 0.60615
# Epoch 107/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1571 - acc: 0.5572 - val_loss: 1.1469 - val_acc: 0.5996
#
# Epoch 00107: val_acc did not improve from 0.60615
# Epoch 108/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1474 - acc: 0.5539 - val_loss: 1.1491 - val_acc: 0.6043
#
# Epoch 00108: val_acc did not improve from 0.60615
# Epoch 109/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1541 - acc: 0.5569 - val_loss: 1.1478 - val_acc: 0.6015
#
# Epoch 00109: val_acc did not improve from 0.60615
# Epoch 110/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1561 - acc: 0.5450 - val_loss: 1.1466 - val_acc: 0.6015
#
# Epoch 00110: val_acc did not improve from 0.60615
# Epoch 111/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1583 - acc: 0.5500 - val_loss: 1.1409 - val_acc: 0.6034
#
# Epoch 00111: val_acc did not improve from 0.60615
# Epoch 112/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1496 - acc: 0.5536 - val_loss: 1.1390 - val_acc: 0.6015
#
# Epoch 00112: val_acc did not improve from 0.60615
# Epoch 113/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1546 - acc: 0.5529 - val_loss: 1.1447 - val_acc: 0.6080
#
# Epoch 00113: val_acc improved from 0.60615 to 0.60801, saving model to weights-best.hdf5
# Epoch 114/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1485 - acc: 0.5432 - val_loss: 1.1437 - val_acc: 0.6034
#
# Epoch 00114: val_acc did not improve from 0.60801
# Epoch 115/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1590 - acc: 0.5506 - val_loss: 1.1414 - val_acc: 0.5931
#
# Epoch 00115: val_acc did not improve from 0.60801
# Epoch 116/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1510 - acc: 0.5518 - val_loss: 1.1418 - val_acc: 0.6024
#
# Epoch 00116: val_acc did not improve from 0.60801
# Epoch 117/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1431 - acc: 0.5613 - val_loss: 1.1469 - val_acc: 0.5922
#
# Epoch 00117: val_acc did not improve from 0.60801
# Epoch 118/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1525 - acc: 0.5542 - val_loss: 1.1532 - val_acc: 0.6052
#
# Epoch 00118: val_acc did not improve from 0.60801
# Epoch 119/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1580 - acc: 0.5534 - val_loss: 1.1498 - val_acc: 0.5950
#
# Epoch 00119: val_acc did not improve from 0.60801
# Epoch 120/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1430 - acc: 0.5593 - val_loss: 1.1444 - val_acc: 0.6024
#
# Epoch 00120: val_acc did not improve from 0.60801
# Epoch 121/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1403 - acc: 0.5664 - val_loss: 1.1449 - val_acc: 0.5978
#
# Epoch 00121: val_acc did not improve from 0.60801
# Epoch 122/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1479 - acc: 0.5509 - val_loss: 1.1383 - val_acc: 0.5968
#
# Epoch 00122: val_acc did not improve from 0.60801
# Epoch 123/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1435 - acc: 0.5557 - val_loss: 1.1408 - val_acc: 0.5978
#
# Epoch 00123: val_acc did not improve from 0.60801
# Epoch 124/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1403 - acc: 0.5575 - val_loss: 1.1468 - val_acc: 0.5987
#
# Epoch 00124: val_acc did not improve from 0.60801
# Epoch 125/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1447 - acc: 0.5550 - val_loss: 1.1452 - val_acc: 0.6034
#
# Epoch 00125: val_acc did not improve from 0.60801
# Epoch 126/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1273 - acc: 0.5641 - val_loss: 1.1413 - val_acc: 0.6034
#
# Epoch 00126: val_acc did not improve from 0.60801
# Epoch 127/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1527 - acc: 0.5569 - val_loss: 1.1513 - val_acc: 0.6080
#
# Epoch 00127: val_acc did not improve from 0.60801
# Epoch 128/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1386 - acc: 0.5619 - val_loss: 1.1489 - val_acc: 0.6034
#
# Epoch 00128: val_acc did not improve from 0.60801
# Epoch 129/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1459 - acc: 0.5569 - val_loss: 1.1495 - val_acc: 0.5950
#
# Epoch 00129: val_acc did not improve from 0.60801
# Epoch 130/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1407 - acc: 0.5623 - val_loss: 1.1482 - val_acc: 0.5931
#
# Epoch 00130: val_acc did not improve from 0.60801
# Epoch 131/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1376 - acc: 0.5532 - val_loss: 1.1444 - val_acc: 0.6015
#
# Epoch 00131: val_acc did not improve from 0.60801
# Epoch 132/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1347 - acc: 0.5652 - val_loss: 1.1499 - val_acc: 0.5996
#
# Epoch 00132: val_acc did not improve from 0.60801
# Epoch 133/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1350 - acc: 0.5521 - val_loss: 1.1447 - val_acc: 0.6015
#
# Epoch 00133: val_acc did not improve from 0.60801
# Epoch 134/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1424 - acc: 0.5500 - val_loss: 1.1450 - val_acc: 0.5987
#
# Epoch 00134: val_acc did not improve from 0.60801
# Epoch 135/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1279 - acc: 0.5633 - val_loss: 1.1471 - val_acc: 0.6061
#
# Epoch 00135: val_acc did not improve from 0.60801
# Epoch 136/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1298 - acc: 0.5633 - val_loss: 1.1474 - val_acc: 0.5940
#
# Epoch 00136: val_acc did not improve from 0.60801
# Epoch 137/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1237 - acc: 0.5649 - val_loss: 1.1470 - val_acc: 0.5959
#
# Epoch 00137: val_acc did not improve from 0.60801
# Epoch 138/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1364 - acc: 0.5613 - val_loss: 1.1480 - val_acc: 0.5931
#
# Epoch 00138: val_acc did not improve from 0.60801
# Epoch 139/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1315 - acc: 0.5621 - val_loss: 1.1473 - val_acc: 0.5978
#
# Epoch 00139: val_acc did not improve from 0.60801
# Epoch 140/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1395 - acc: 0.5646 - val_loss: 1.1418 - val_acc: 0.5996
#
# Epoch 00140: val_acc did not improve from 0.60801
# Epoch 141/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1246 - acc: 0.5642 - val_loss: 1.1479 - val_acc: 0.6006
#
# Epoch 00141: val_acc did not improve from 0.60801
# Epoch 142/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1273 - acc: 0.5527 - val_loss: 1.1440 - val_acc: 0.6052
#
# Epoch 00142: val_acc did not improve from 0.60801
# Epoch 143/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1254 - acc: 0.5662 - val_loss: 1.1451 - val_acc: 0.6006
#
# Epoch 00143: val_acc did not improve from 0.60801
# Epoch 144/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1313 - acc: 0.5615 - val_loss: 1.1493 - val_acc: 0.5922
#
# Epoch 00144: val_acc did not improve from 0.60801
# Epoch 145/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1285 - acc: 0.5559 - val_loss: 1.1495 - val_acc: 0.5987
#
# Epoch 00145: val_acc did not improve from 0.60801
# Epoch 146/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1308 - acc: 0.5677 - val_loss: 1.1533 - val_acc: 0.5978
#
# Epoch 00146: val_acc did not improve from 0.60801
# Epoch 147/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1277 - acc: 0.5670 - val_loss: 1.1485 - val_acc: 0.5978
#
# Epoch 00147: val_acc did not improve from 0.60801
# Epoch 148/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1232 - acc: 0.5674 - val_loss: 1.1454 - val_acc: 0.6089
#
# Epoch 00148: val_acc improved from 0.60801 to 0.60894, saving model to weights-best.hdf5
# Epoch 149/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1204 - acc: 0.5669 - val_loss: 1.1428 - val_acc: 0.6052
#
# Epoch 00149: val_acc did not improve from 0.60894
# Epoch 150/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1332 - acc: 0.5639 - val_loss: 1.1434 - val_acc: 0.6015
#
# Epoch 00150: val_acc did not improve from 0.60894
# Epoch 151/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1254 - acc: 0.5618 - val_loss: 1.1496 - val_acc: 0.5987
#
# Epoch 00151: val_acc did not improve from 0.60894
# Epoch 152/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1343 - acc: 0.5519 - val_loss: 1.1478 - val_acc: 0.6061
#
# Epoch 00152: val_acc did not improve from 0.60894
# Epoch 153/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1192 - acc: 0.5631 - val_loss: 1.1482 - val_acc: 0.6006
#
# Epoch 00153: val_acc did not improve from 0.60894
# Epoch 154/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1152 - acc: 0.5596 - val_loss: 1.1478 - val_acc: 0.5912
#
# Epoch 00154: val_acc did not improve from 0.60894
# Epoch 155/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1313 - acc: 0.5669 - val_loss: 1.1500 - val_acc: 0.5922
#
# Epoch 00155: val_acc did not improve from 0.60894
# Epoch 156/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1347 - acc: 0.5573 - val_loss: 1.1543 - val_acc: 0.5950
#
# Epoch 00156: val_acc did not improve from 0.60894
# Epoch 157/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1199 - acc: 0.5638 - val_loss: 1.1520 - val_acc: 0.5968
#
# Epoch 00157: val_acc did not improve from 0.60894
# Epoch 158/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1238 - acc: 0.5624 - val_loss: 1.1545 - val_acc: 0.6015
#
# Epoch 00158: val_acc did not improve from 0.60894
# Epoch 159/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1110 - acc: 0.5665 - val_loss: 1.1513 - val_acc: 0.6052
#
# Epoch 00159: val_acc did not improve from 0.60894
# Epoch 160/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1209 - acc: 0.5636 - val_loss: 1.1565 - val_acc: 0.6015
#
# Epoch 00160: val_acc did not improve from 0.60894
# Epoch 161/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1186 - acc: 0.5593 - val_loss: 1.1565 - val_acc: 0.5987
#
# Epoch 00161: val_acc did not improve from 0.60894
# Epoch 162/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1101 - acc: 0.5642 - val_loss: 1.1544 - val_acc: 0.5968
#
# Epoch 00162: val_acc did not improve from 0.60894
# Epoch 163/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1149 - acc: 0.5638 - val_loss: 1.1524 - val_acc: 0.5922
#
# Epoch 00163: val_acc did not improve from 0.60894
# Epoch 164/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1138 - acc: 0.5693 - val_loss: 1.1521 - val_acc: 0.6024
#
# Epoch 00164: val_acc did not improve from 0.60894
# Epoch 165/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1146 - acc: 0.5626 - val_loss: 1.1522 - val_acc: 0.5875
#
# Epoch 00165: val_acc did not improve from 0.60894
# Epoch 166/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1186 - acc: 0.5642 - val_loss: 1.1530 - val_acc: 0.5940
#
# Epoch 00166: val_acc did not improve from 0.60894
# Epoch 167/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1142 - acc: 0.5679 - val_loss: 1.1538 - val_acc: 0.5931
#
# Epoch 00167: val_acc did not improve from 0.60894
# Epoch 168/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1084 - acc: 0.5721 - val_loss: 1.1518 - val_acc: 0.5978
#
# Epoch 00168: val_acc did not improve from 0.60894
# Epoch 169/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1227 - acc: 0.5590 - val_loss: 1.1517 - val_acc: 0.5950
#
# Epoch 00169: val_acc did not improve from 0.60894
# Epoch 170/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1219 - acc: 0.5582 - val_loss: 1.1542 - val_acc: 0.5968
#
# Epoch 00170: val_acc did not improve from 0.60894
# Epoch 171/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1141 - acc: 0.5624 - val_loss: 1.1595 - val_acc: 0.6034
#
# Epoch 00171: val_acc did not improve from 0.60894
# Epoch 172/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1134 - acc: 0.5582 - val_loss: 1.1561 - val_acc: 0.5987
#
# Epoch 00172: val_acc did not improve from 0.60894
# Epoch 173/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1099 - acc: 0.5685 - val_loss: 1.1525 - val_acc: 0.5968
#
# Epoch 00173: val_acc did not improve from 0.60894
# Epoch 174/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1135 - acc: 0.5661 - val_loss: 1.1584 - val_acc: 0.5968
#
# Epoch 00174: val_acc did not improve from 0.60894
# Epoch 175/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1278 - acc: 0.5628 - val_loss: 1.1587 - val_acc: 0.6006
#
# Epoch 00175: val_acc did not improve from 0.60894
# Epoch 176/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1100 - acc: 0.5692 - val_loss: 1.1578 - val_acc: 0.5978
#
# Epoch 00176: val_acc did not improve from 0.60894
# Epoch 177/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1212 - acc: 0.5707 - val_loss: 1.1601 - val_acc: 0.6043
#
# Epoch 00177: val_acc did not improve from 0.60894
# Epoch 178/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1003 - acc: 0.5726 - val_loss: 1.1588 - val_acc: 0.6006
#
# Epoch 00178: val_acc did not improve from 0.60894
# Epoch 179/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1101 - acc: 0.5659 - val_loss: 1.1607 - val_acc: 0.6043
#
# Epoch 00179: val_acc did not improve from 0.60894
# Epoch 180/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1029 - acc: 0.5736 - val_loss: 1.1585 - val_acc: 0.6034
#
# Epoch 00180: val_acc did not improve from 0.60894
# Epoch 181/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1143 - acc: 0.5649 - val_loss: 1.1579 - val_acc: 0.6015
#
# Epoch 00181: val_acc did not improve from 0.60894
# Epoch 182/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1236 - acc: 0.5611 - val_loss: 1.1632 - val_acc: 0.5996
#
# Epoch 00182: val_acc did not improve from 0.60894
# Epoch 183/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1260 - acc: 0.5593 - val_loss: 1.1562 - val_acc: 0.5940
#
# Epoch 00183: val_acc did not improve from 0.60894
# Epoch 184/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1152 - acc: 0.5705 - val_loss: 1.1543 - val_acc: 0.5931
#
# Epoch 00184: val_acc did not improve from 0.60894
# Epoch 185/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1022 - acc: 0.5687 - val_loss: 1.1519 - val_acc: 0.6015
#
# Epoch 00185: val_acc did not improve from 0.60894
# Epoch 186/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1202 - acc: 0.5606 - val_loss: 1.1518 - val_acc: 0.6089
#
# Epoch 00186: val_acc improved from 0.60894 to 0.60894, saving model to weights-best.hdf5
# Epoch 187/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1071 - acc: 0.5726 - val_loss: 1.1525 - val_acc: 0.6061
#
# Epoch 00187: val_acc did not improve from 0.60894
# Epoch 188/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1119 - acc: 0.5710 - val_loss: 1.1542 - val_acc: 0.6061
#
# Epoch 00188: val_acc did not improve from 0.60894
# Epoch 189/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1141 - acc: 0.5675 - val_loss: 1.1554 - val_acc: 0.6015
#
# Epoch 00189: val_acc did not improve from 0.60894
# Epoch 190/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1233 - acc: 0.5619 - val_loss: 1.1550 - val_acc: 0.6136
#
# Epoch 00190: val_acc improved from 0.60894 to 0.61359, saving model to weights-best.hdf5
# Epoch 191/200
# 6086/6086 [==============================] - 0s 18us/step - loss: 1.1000 - acc: 0.5736 - val_loss: 1.1563 - val_acc: 0.6164
#
# Epoch 00191: val_acc improved from 0.61359 to 0.61639, saving model to weights-best.hdf5
# Epoch 192/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1115 - acc: 0.5734 - val_loss: 1.1547 - val_acc: 0.6052
#
# Epoch 00192: val_acc did not improve from 0.61639
# Epoch 193/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.0967 - acc: 0.5818 - val_loss: 1.1520 - val_acc: 0.6006
#
# Epoch 00193: val_acc did not improve from 0.61639
# Epoch 194/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.0974 - acc: 0.5757 - val_loss: 1.1514 - val_acc: 0.6015
#
# Epoch 00194: val_acc did not improve from 0.61639
# Epoch 195/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.0973 - acc: 0.5751 - val_loss: 1.1527 - val_acc: 0.5996
#
# Epoch 00195: val_acc did not improve from 0.61639
# Epoch 196/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.0979 - acc: 0.5754 - val_loss: 1.1579 - val_acc: 0.6061
#
# Epoch 00196: val_acc did not improve from 0.61639
# Epoch 197/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1074 - acc: 0.5624 - val_loss: 1.1558 - val_acc: 0.6080
#
# Epoch 00197: val_acc did not improve from 0.61639
# Epoch 198/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1105 - acc: 0.5716 - val_loss: 1.1525 - val_acc: 0.6043
#
# Epoch 00198: val_acc did not improve from 0.61639
# Epoch 199/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.1076 - acc: 0.5636 - val_loss: 1.1520 - val_acc: 0.6061
#
# Epoch 00199: val_acc did not improve from 0.61639
# Epoch 200/200
# 6086/6086 [==============================] - 0s 17us/step - loss: 1.0984 - acc: 0.5708 - val_loss: 1.1501 - val_acc: 0.6006
#
# Epoch 00200: val_acc did not improve from 0.61639

# %%
train_loss = model_history.history['loss']
train_acc = model_history.history['acc']
valid_loss = model_history.history['val_loss']
valid_acc = model_history.history['val_acc']

# %%
plt.plot(train_loss, 'b', label='train')
plt.plot(valid_loss, 'r', label='valid')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(train_acc, 'b', label='train')
plt.plot(valid_acc, 'r', label='valid')
plt.legend(loc=4)
plt.title("Accuracy")
plt.show()

# %%
# save model
#model.save('my_model.h5')

# %% [markdown]
# ## 取訓練時最佳的結果來做test預測

# %%
# load model
another_model = load_model(filepath)
#another_model = tf.keras.models.load_model('my_model.h5')

# %%
y_test_pred = model.predict_classes(x_test)

# %%
## 將預測結果與ID做combine
prediction = pd.DataFrame(y_test_pred, columns=['class'])
result = pd.concat([x_test_id, prediction], axis=1)
result.head()
# Out:
#                              id  class
# 0  MTA5MTEwOTYxMzM0NzA2NDEzNzM=      2
# 1  MTY0OTUyMTM2MDExMjg3MjczMjU=      1
# 2  MTQ0ODU1OTEzOTU1NTAyNzI4NjE=      4
# 3  MTY1ODg1MzEwNzYzNDUzMDUwNTM=      3
# 4  MTY0NTg2OTA5MTkzOTE2MTc1MTc=      5

# %%
#儲存結果
result.to_csv('submission_dl.csv', index=False)
